# %%
import numpy as np
import glob
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import tensorflow as tf

# %%
today = datetime.date.today()
date = today.strftime("%B%d")
date
# Out:
# 'August21'

# %% [markdown]
# Load the tensorboard log files into pandas dataframe

# %%
# Gather data
data = []
logs = glob.glob(rf".\logs\wheeled_random_beocat_Aug21\*\*")
for log in logs:
    experiment_info = log.split('\\')[-2].split('_')
    algorithm = experiment_info[0]
    st = experiment_info[1]
    # print(log)
    print(log.split('\\'))
    print(experiment_info)

    for e in tf.compat.v1.train.summary_iterator(log):
        for v in e.summary.value:
            if v.tag == 'rollout/ep_rew_mean':
                data.append({
                    'algorithm': algorithm,
                    'set': st,
                    'step': e.step,
                    'reward': v.simple_value
                })
df = pd.DataFrame(data)
df.to_csv(rf"results\wheeled_random_raw_beocat_{date}.csv")
df
# Out:
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'A2C_set1_0', 'events.out.tfevents.1755616997.wizard37.3740347.0']
# ['A2C', 'set1', '0']
# WARNING:tensorflow:From C:\Users\choton\AppData\Local\Temp\ipykernel_7884\2481604957.py:12: The name tf.train.summary_iterator is deprecated. Please use tf.compat.v1.train.summary_iterator instead.
#
# WARNING:tensorflow:From c:\Users\choton\miniconda3\envs\rl4pag\Lib\site-packages\tensorflow\python\summary\summary_iterator.py:27: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'A2C_set1_0', 'events.out.tfevents.1755625638.warlock25.2882412.0']
# ['A2C', 'set1', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'A2C_set2_0', 'events.out.tfevents.1755616997.wizard17.3302973.0']
# ['A2C', 'set2', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'A2C_set3_0', 'events.out.tfevents.1755616997.wizard18.1493420.0']
# ['A2C', 'set3', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'A2C_set4_0', 'events.out.tfevents.1755616997.dwarf33.1373591.0']
# ['A2C', 'set4', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'A2C_set5_0', 'events.out.tfevents.1755616997.dwarf33.1373592.0']
# ['A2C', 'set5', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'A2C_set6_0', 'events.out.tfevents.1755618052.warlock32.35533.0']
# ['A2C', 'set6', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'A2C_set7_0', 'events.out.tfevents.1755618052.warlock32.35532.0']
# ['A2C', 'set7', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'A2C_set8_0', 'events.out.tfevents.1755618052.warlock32.35531.0']
# ['A2C', 'set8', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'ARS_set1_0', 'events.out.tfevents.1755623760.wizard38.2956156.0']
# ['ARS', 'set1', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'ARS_set2_0', 'events.out.tfevents.1755623760.wizard38.2956155.0']
# ['ARS', 'set2', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'ARS_set3_0', 'events.out.tfevents.1755624871.wizard32.2801989.0']
# ['ARS', 'set3', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'ARS_set3_0', 'events.out.tfevents.1755628855.warlock32.87287.0']
# ['ARS', 'set3', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'ARS_set4_0', 'events.out.tfevents.1755625078.dwarf31.807242.0']
# ['ARS', 'set4', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'ARS_set5_0', 'events.out.tfevents.1755625078.dwarf31.807243.0']
# ['ARS', 'set5', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'ARS_set6_0', 'events.out.tfevents.1755625611.warlock25.2881390.0']
# ['ARS', 'set6', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'ARS_set7_0', 'events.out.tfevents.1755625611.warlock25.2881391.0']
# ['ARS', 'set7', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'ARS_set8_0', 'events.out.tfevents.1755625611.wizard34.1309223.0']
# ['ARS', 'set8', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'CrossQ_set1_0', 'events.out.tfevents.1755616672.hero37.2496211.0']
# ['CrossQ', 'set1', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'CrossQ_set2_0', 'events.out.tfevents.1755616672.hero37.2496210.0']
# ['CrossQ', 'set2', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'CrossQ_set3_0', 'events.out.tfevents.1755616709.hero43.3207008.0']
# ['CrossQ', 'set3', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'CrossQ_set4_0', 'events.out.tfevents.1755616709.hero43.3207007.0']
# ['CrossQ', 'set4', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'CrossQ_set5_0', 'events.out.tfevents.1755616997.dwarf38.2541195.0']
# ['CrossQ', 'set5', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'CrossQ_set6_0', 'events.out.tfevents.1755616997.dwarf38.2541196.0']
# ['CrossQ', 'set6', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'CrossQ_set7_0', 'events.out.tfevents.1755616997.dwarf36.785104.0']
# ['CrossQ', 'set7', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'CrossQ_set8_0', 'events.out.tfevents.1755616997.dwarf36.785105.0']
# ['CrossQ', 'set8', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set1_0', 'events.out.tfevents.1755618740.hero38.1635652.0']
# ['PPO', 'set1', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set1_0', 'events.out.tfevents.1755625827.warlock25.2884528.0']
# ['PPO', 'set1', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set2_0', 'events.out.tfevents.1755618740.hero38.1635653.0']
# ['PPO', 'set2', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set2_0', 'events.out.tfevents.1755629859.warlock25.2914256.0']
# ['PPO', 'set2', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set3_0', 'events.out.tfevents.1755618941.wizard18.1504374.0']
# ['PPO', 'set3', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set4_0', 'events.out.tfevents.1755619529.warlock25.2833517.0']
# ['PPO', 'set4', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set4_0', 'events.out.tfevents.1755629481.dwarf30.725340.0']
# ['PPO', 'set4', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set5_0', 'events.out.tfevents.1755619529.warlock25.2833516.0']
# ['PPO', 'set5', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set5_0', 'events.out.tfevents.1755629481.dwarf30.725341.0']
# ['PPO', 'set5', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set6_0', 'events.out.tfevents.1755619529.warlock25.2833515.0']
# ['PPO', 'set6', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set6_0', 'events.out.tfevents.1755629209.warlock32.90188.0']
# ['PPO', 'set6', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set7_0', 'events.out.tfevents.1755619386.dwarf33.1379865.0']
# ['PPO', 'set7', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'PPO_set8_0', 'events.out.tfevents.1755619523.warlock32.43714.0']
# ['PPO', 'set8', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TQC_set1_0', 'events.out.tfevents.1755616997.dwarf37.1815088.0']
# ['TQC', 'set1', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TQC_set2_0', 'events.out.tfevents.1755616997.dwarf37.1815089.0']
# ['TQC', 'set2', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TQC_set3_0', 'events.out.tfevents.1755616997.dwarf39.1547742.0']
# ['TQC', 'set3', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TQC_set4_0', 'events.out.tfevents.1755616997.dwarf39.1547741.0']
# ['TQC', 'set4', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TQC_set5_0', 'events.out.tfevents.1755616997.dwarf23.995826.0']
# ['TQC', 'set5', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TQC_set6_0', 'events.out.tfevents.1755616997.warlock33.3579587.0']
# ['TQC', 'set6', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TQC_set7_0', 'events.out.tfevents.1755616997.warlock33.3579586.0']
# ['TQC', 'set7', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TQC_set8_0', 'events.out.tfevents.1755616997.wizard34.1252645.0']
# ['TQC', 'set8', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set1_0', 'events.out.tfevents.1755619784.wizard17.3311202.0']
# ['TRPO', 'set1', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set1_0', 'events.out.tfevents.1755625638.warlock25.2882635.0']
# ['TRPO', 'set1', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set1_0', 'events.out.tfevents.1755629481.wizard29.394223.0']
# ['TRPO', 'set1', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set2_0', 'events.out.tfevents.1755619882.warlock32.45493.0']
# ['TRPO', 'set2', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set3_0', 'events.out.tfevents.1755619936.warlock32.45852.0']
# ['TRPO', 'set3', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set4_0', 'events.out.tfevents.1755620580.dwarf33.1382910.0']
# ['TRPO', 'set4', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set5_0', 'events.out.tfevents.1755620746.hero38.1664463.0']
# ['TRPO', 'set5', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set5_0', 'events.out.tfevents.1755627383.warlock25.2895454.0']
# ['TRPO', 'set5', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set6_0', 'events.out.tfevents.1755622834.dwarf22.2422286.0']
# ['TRPO', 'set6', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set6_0', 'events.out.tfevents.1755630748.warlock32.97547.0']
# ['TRPO', 'set6', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set7_0', 'events.out.tfevents.1755622834.dwarf22.2422285.0']
# ['TRPO', 'set7', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set7_0', 'events.out.tfevents.1755631532.warlock25.2926772.0']
# ['TRPO', 'set7', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set8_0', 'events.out.tfevents.1755623802.wizard05.3616941.0']
# ['TRPO', 'set8', '0']
# ['.', 'logs', 'wheeled_random_beocat_Aug21', 'TRPO_set8_0', 'events.out.tfevents.1755633629.warlock25.2941117.0']
# ['TRPO', 'set8', '0']
#       algorithm   set     step        reward
# 0           A2C  set1     2000 -89263.390625
# 1           A2C  set1     4000 -88692.328125
# 2           A2C  set1     6000 -80913.742188
# 3           A2C  set1     8000 -78909.929688
# 4           A2C  set1    10000 -76183.390625
# ...         ...   ...      ...           ...
# 86253      TRPO  set8  4984832 -47485.699219
# 86254      TRPO  set8  4988928 -48588.933594
# 86255      TRPO  set8  4993024 -46780.234375
# 86256      TRPO  set8  4997120 -44793.050781
# 86257      TRPO  set8  5001216 -43831.851562
#
# [86258 rows x 4 columns]

# %%
df['algorithm'].unique()
# Out:
# array(['A2C', 'ARS', 'CrossQ', 'PPO', 'TQC', 'TRPO'], dtype=object)

# %%
# Scaling the rewards for visualization
df['reward_scaled'] = df['reward'] / 1000000
df['reward_scaled'] = df['reward_scaled'].clip(lower=-2)

# %%
# Define a common x-axis (based on min-max steps across all algorithms)
min_step = df['step'].min()
max_step = df['step'].max()
common_steps = np.linspace(min_step, max_step, 200)

plt.rcParams.update({'font.size': 18})
plt.figure(figsize=(10,7))

# Group by algorithm
for algo, algo_df in df.groupby('algorithm'):
    runs = []

    # For each run (set), interpolate rewards to common steps
    for run_id, run_df in algo_df.groupby('set'):
        x = run_df['step'].values
        y = run_df['reward_scaled'].values
        interp_rewards = np.interp(common_steps, x, y)
        runs.append(interp_rewards)

    runs = np.array(runs)
    mean_rewards = runs.mean(axis=0)
    std_rewards = runs.std(axis=0)

    # Plot with variance shading
    plt.plot(common_steps, mean_rewards, label=algo, linewidth=2)
    plt.fill_between(common_steps, mean_rewards - std_rewards, mean_rewards + std_rewards, alpha=0.2)

plt.xlabel("Step")
plt.ylabel("Reward (x$10^6$)")
# plt.title("RL Algorithms Reward Curves with Variance")
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.savefig(rf"plots/wheeled_random_beocat_{date}.png")
plt.show()

# %%
a2c_df = df[df['algorithm']=='A2C']
ppo_df = df[df['algorithm']=='PPO']
trpo_df = df[df['algorithm']=='TRPO']
ars_df = df[df['algorithm']=='ARS']
crossq_df = df[df['algorithm']=='CrossQ']
tqc_df = df[df['algorithm']=='TQC']


a2c_data = {"Setting": "AB", 
            "Algorithm": "A2C", 
            "Mean": a2c_df['reward'].mean(),
            "SD": a2c_df['reward'].std(),
            "Max": a2c_df['reward'].max(),
            "Range": (a2c_df['reward'].max() - a2c_df['reward'].min())}
ppo_data = {"Setting": "AB", 
            "Algorithm": "PPO", 
            "Mean": ppo_df['reward'].mean(),
            "SD": ppo_df['reward'].std(),
            "Max": ppo_df['reward'].max(),
            "Range": (ppo_df['reward'].max() - ppo_df['reward'].min())}
trpo_data = {"Setting": "AB", 
            "Algorithm": "TRPO", 
            "Mean": trpo_df['reward'].mean(),
            "SD": trpo_df['reward'].std(),
            "Max": trpo_df['reward'].max(),
            "Range": (trpo_df['reward'].max() - trpo_df['reward'].min())}
ars_data = {"Setting": "AB", 
            "Algorithm": "ARS", 
            "Mean": ars_df['reward'].mean(),
            "SD": ars_df['reward'].std(),
            "Max": ars_df['reward'].max(),
            "Range": (ars_df['reward'].max() - ars_df['reward'].min())}
crossq_data = {"Setting": "AB", 
            "Algorithm": "CrossQ", 
            "Mean": crossq_df['reward'].mean(),
            "SD": crossq_df['reward'].std(),
            "Max": crossq_df['reward'].max(),
            "Range": (crossq_df['reward'].max() - crossq_df['reward'].min())}
tqc_data = {"Setting": "AB", 
            "Algorithm": "TQC", 
            "Mean": tqc_df['reward'].mean(),
            "SD": tqc_df['reward'].std(),
            "Max": tqc_df['reward'].max(),
            "Range": (tqc_df['reward'].max() - tqc_df['reward'].min())}


set_tab_df = pd.DataFrame([a2c_data, ppo_data, trpo_data, ars_data, crossq_data, tqc_data])
set_tab_df
# Out:
#   Setting Algorithm          Mean            SD            Max          Range
# 0      AB       A2C -95972.176841   4539.168848  -70700.593750   30011.867188
# 1      AB       PPO -96296.106243   4374.029843  -63067.281250   38479.843750
# 2      AB      TRPO -44831.610361  27743.266093   16260.944336  118246.842773
# 3      AB       ARS  -5295.109548  12253.000202   18952.000000  107393.718750
# 4      AB    CrossQ -83017.017639  19429.549611  115718.210938  216983.210938
# 5      AB       TQC -71808.759080  24753.375397   14393.159180  117600.706055

# %%
set_tab_df_sc = set_tab_df.select_dtypes(include='number') / 1000000
set_tab_df_sc.insert(0, 'Setting', set_tab_df['Setting'])
set_tab_df_sc.insert(1, 'Algorithm', set_tab_df['Algorithm'])
set_tab_df_sc
# Out:
#   Setting Algorithm      Mean        SD       Max     Range
# 0      AB       A2C -0.095972  0.004539 -0.070701  0.030012
# 1      AB       PPO -0.096296  0.004374 -0.063067  0.038480
# 2      AB      TRPO -0.044832  0.027743  0.016261  0.118247
# 3      AB       ARS -0.005295  0.012253  0.018952  0.107394
# 4      AB    CrossQ -0.083017  0.019430  0.115718  0.216983
# 5      AB       TQC -0.071809  0.024753  0.014393  0.117601

# %%
set_tab_df_sc.to_csv(rf"results/wheeled_random_beocat_results_{date}.csv")
