# %% [markdown]
# Experiment date and environment

# %%
date_n_env = "apr11_env1_double" # Experiment date and environment

# %% [markdown]
# Import libraries:

# %%
# Import libraries
import pygame
import gymnasium as gym
import numpy as np
import copy
import itertools
np.random.seed(33) # seeding
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.11.11)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# Necessary functions:

# %%
# convert binary list to decimal
def binary_list_to_decimal(bin_list):
    bin = ''
    for b in bin_list:
        bin += str(b)
    dec = int(bin,2)
    return dec

# Function to check if a point is inside a polygon (Ray-casting algorithm)
def is_inside_polygon(point, poly):
    x, y = point
    inside = False
    n = len(poly)
    p1x, p1y = poly[0]
    for i in range(n + 1):
        p2x, p2y = poly[i % n]
        if min(p1y, p2y) < y <= max(p1y, p2y) and x <= max(p1x, p2x):
            if p1y != p2y:
                xinters = (y - p1y) * (p2x - p1x) / (p2y - p1y) + p1x
            if p1x == p2x or x <= xinters:
                inside = not inside
        p1x, p1y = p2x, p2y
    return inside

# Function to return minimum distance in a list of points
def min_dist(x):
    x = np.array(x).astype('float32')
    dists = []
    for p1, p2 in itertools.combinations(x, 2):
        dist = np.linalg.norm(p1-p2)
        dists.append(dist)
    return float(np.min(dists))

# %% [markdown]
# Open the experiment file to read the polygon

# %%
experiments_path = r'C:\Users\choton\OneDrive - Kansas State University\PhD Projects\Reinforcement Learning\Codes\for_coRL\github\FlowBotic\experiment_sets.txt'
# Read the experiments file and select the experiment
with open(experiments_path, 'r') as experiment_file:
    codes = experiment_file.read()
    exec(codes) # execute
selected_experiment = set1 # Select the experiment set
selected_experiment
# Out:
# {'field': [(43.0, 24.0), (20.0, 47.0), (13.0, 34.0), (12.0, 9.0), (22.0, 0.0)],
#  'init_positions': [array([14., 34.]), array([40., 25.]), array([20., 40.])],
#  'infected_locations': {(15.0, 10.0),
#   (22.0, 13.0),
#   (25.0, 20.0),
#   (25.0, 35.0),
#   (26.0, 21.0),
#   (35.0, 25.0)}}

# %% [markdown]
# Scaling the values (may need to change later)

# %%
sf = 10
selected_experiment['field'] = [(x*sf, y*sf) for (x,y) in selected_experiment['field']]
selected_experiment['infected_locations'] = [(x*sf, y*sf) for (x,y) in selected_experiment['infected_locations']]
selected_experiment['init_positions'] = [v*sf for v in selected_experiment['init_positions']]
selected_experiment, len(selected_experiment['init_positions']), len(np.unique(selected_experiment['init_positions'], axis=0))
# Out:
# ({'field': [(430.0, 240.0),
#    (200.0, 470.0),
#    (130.0, 340.0),
#    (120.0, 90.0),
#    (220.0, 0.0)],
#   'init_positions': [array([140., 340.]),
#    array([400., 250.]),
#    array([200., 400.])],
#   'infected_locations': [(260.0, 210.0),
#    (150.0, 100.0),
#    (220.0, 130.0),
#    (250.0, 350.0),
#    (350.0, 250.0),
#    (250.0, 200.0)]},
#  3,
#  3)

# %%
class MultiRobotEnv(gym.Env):
    metadata = {'render_modes': ['human', 'print', 'rgb_array'], "render_fps": 4}
    def __init__(self, render_mode=None, field_info=copy.deepcopy(selected_experiment), wind_par=[0,0], num_robots=2):
        super(MultiRobotEnv, self).__init__()
        # Screen dimensions
        self.edge_buffer = 10 # Boundary above the max values
        self.poly_vertices = field_info['field'] # Vertices of polygon
        self.xs, self.ys = zip(*field_info['field']) # x and y values of the vertices of the polygonal field
        self.WIDTH, self.HEIGHT = 1000, 1000 # Use this if we want to have fixed width and height  
        # self.WIDTH, self.HEIGHT = max(self.xs) + self.edge_buffer, max(self.ys) + self.edge_buffer        

        # Robot parameters
        self.num_robots = num_robots # Rendering error if more than 7
        self.init_robot_positions = np.array(field_info['init_positions'])[:self.num_robots]
        self.robot_size = 10
        self.mass = 1.0
        self.thrust_power = 0.5  # Force applied per action
        self.max_speed = 5  # Maximum speed    
        self.min_speed = -5 # Minimum speed
        self.min_positions = np.zeros(self.num_robots*2) # Minimum positions
        self.max_positions = np.array([[self.WIDTH, self.HEIGHT] for _ in range(self.num_robots)]) # Maximum positions
        self.min_velocities = np.array([[self.min_speed, self.min_speed] for _ in range(self.num_robots)]) # Min speed list
        self.max_velocities = np.array([[self.max_speed, self.max_speed] for _ in range(self.num_robots)]) # Max speed list
        self.wind_f_a, self.wind_beta_a = wind_par # Wind parameters: magnitude and angle

        # infected locations
        self.initial_inf_locations = field_info['infected_locations']
        self.infected_size = 10 # Radius of infected locations
        self.infected_length = len(field_info['infected_locations'])
        self.infected_state_length = 2**(self.infected_length) # 2**5, binary to decimal

        # Action space: thrust in x and y directions for each robot
        self.action_space = gym.spaces.Box(low=-1.0, high=1.0, shape=(self.num_robots, 2), dtype=np.float32)

        # Observation space: position and velocity (x, y, vx, vy) for each robot + infected location        
        self.observation_space = gym.spaces.Box( # The (visited) weed locations are tracked on the observation space
                    low = np.concatenate((self.min_positions.flatten(), self.min_velocities.flatten(), np.array([0]))), # Lowest positions and velocities
                    high = np.concatenate((self.max_positions.flatten(), self.max_velocities.flatten(), np.array([self.infected_state_length - 1]))), # highest positions and velocities
                    dtype=np.float32)

        assert render_mode is None or render_mode in self.metadata["render_modes"] # Check if the render mode is correct
        self.render_mode = render_mode
        self.screen = None
        self.clock = None
        # If human-rendering is used, `self.screen` will be a reference to the screen that we draw to. `self.clock` will be a clock that is used
        # to ensure that the environment is rendered at the correct framerate in human-mode. They will remain `None` until human-mode is used for the first time.   

        # Reset the environment and start
        self.reset()
    
    def _get_obs(self):
        info = {f'robot{i}': self.robot_positions[i] for i in range(self.num_robots)} # Current position of each robot
        infected = binary_list_to_decimal(list(self.infected_dict.values())) # Convert the binary list of infected locations to a decimal value
        state = np.concatenate((self.robot_positions.flatten(), self.robot_velocities.flatten(), np.array([infected])), dtype=np.float32) # Current state of the robots
        return state, info        

    def reset(self, seed=None, options={}):
        # Reset the visited states and counts
        self.step_count = 0
        self.visited = set()
        self.infected_locations = copy.deepcopy(self.initial_inf_locations) # Initial infected locations
        self.infected_dict = {v:0 for v in self.infected_locations} # 0 for unvisited infected locations, 1 for visited
        self.robot_positions = copy.deepcopy(self.init_robot_positions) # Initial positions of each robot
        self.robot_velocities = np.zeros((self.num_robots, 2)) # Initial velocities of each robot (zero)
        return self._get_obs()
    
    def step(self, actions):
        terminated, truncated = False, False
        rewards = 0
        self.step_count += 1
        for i in range(self.num_robots): # For every robot
            ax, ay = actions[i] * self.thrust_power # What actions to take

            # Update velocity
            self.robot_velocities[i][0] += ax / self.mass + self.wind_f_a * np.cos(np.radians(self.wind_beta_a))
            self.robot_velocities[i][1] += ay / self.mass + self.wind_f_a * np.sin(np.radians(self.wind_beta_a))

            # Limit velocity
            self.robot_velocities[i] = np.clip(self.robot_velocities[i], self.min_speed, self.max_speed)

            # Predict new position
            new_position = self.robot_positions[i] + self.robot_velocities[i]

            # Boundary conditions (keep robot within polygon)
            if is_inside_polygon(new_position, self.poly_vertices):
                pass
            else: # Hits the wall!
                rewards -= 10000 # Medium negative reward for hitting the wall
                self.robot_velocities[i][:] = 0 # Stop movement

            # Update position
            self.robot_positions[i] += self.robot_velocities[i]
            
            # Boundary conditions (keep robot within screen)
            self.robot_positions[i] = np.clip(self.robot_positions[i], [0, 0], [self.WIDTH, self.HEIGHT])

            # Check if location is visited before, and add it to the visited locations
            if tuple(self.robot_positions[i]) in self.visited:
                rewards -= 100 # Small negative reward for visiting previous location
            else:
                rewards -= 10 # Very small negative reward for visiting new locations
            self.visited.add(tuple(self.robot_positions[i]))            

            # Check if any infected location is visited        
            nearby_infected_locations = [] # To store the nearby infected locations
            for j, inf_loc in enumerate(self.infected_locations): # Loop through each infected location
                dist = np.linalg.norm(self.robot_positions[i]-inf_loc) # Distance between robot position and infected location
                if dist <= self.infected_size: # If the distance is within the radius of the infected location size
                    nearby_infected_locations.append(inf_loc) # Add the infected location
                    rewards += 10000 # Medium positive rewards for visiting each infected location
                    # input("Pause!") # Only pause if you want to visualize visiting infected locations
            for inf_loc in nearby_infected_locations:
                self.infected_locations.remove(inf_loc) # Delete each visited infected location
                self.infected_dict[tuple(inf_loc)] = 1 # Update the infected dictionary
        
        # Check if all infected locations are visited
        if len(self.infected_locations) == 0:
            rewards += 100000 # Big positive rewards for visiting all infected locations
            terminated = True
        
        # Check if any collisions occurred
        if self.num_robots > 1:
            min_dist_between_robots = min_dist(self.robot_positions) # Minimum distance between robots
            if min_dist_between_robots < self.robot_size:
                rewards = -100000 # Big negative rewards for collisions
                terminated = True

        obs, info = self._get_obs() # Get the updated observations
        # rewards = rewards * self.gamma ** self.step_count
        return obs, rewards, terminated, truncated, info
    
    def render(self):
        # Initialize pygame
        if self.screen is None and self.render_mode == "human": # Initialize pygame if it is not initialized
            pygame.init()
            pygame.display.init()
            self.screen = pygame.display.set_mode((self.WIDTH, self.HEIGHT))
            pygame.display.set_caption("Multi-robot RL Environment")
            if self.clock is None:
                self.clock = pygame.time.Clock()
                self.running = True
        
        self.screen.fill((255, 255, 255)) # White color for the background
        colors = [(255, 0, 0), (0, 255, 0), (0, 0, 255), (255, 128, 0), (128, 0, 255), (255, 0, 255), (128, 128, 128)]  # Colors for each robot: Red, Green, Blue, Orange, Violet, Pink, Grey
        pix_size = 10

        # Draw the polygon
        # pixel_poly_vertices = [(point[0] * pix_size, point[1] * pix_size) for point in self.poly_vertices]
        pygame.draw.polygon(surface=self.screen, 
                            color=(255, 255, 0), # Yello color for the polygon
                            points=self.poly_vertices)
        
        # Draw the visited regions
        for point in self.visited:
            pygame.draw.circle(self.screen, pygame.Color(100, 100, 100, a=0.2), point, pix_size/2) # Light grey color for visited regions, with transparency alpha

        # Draw robots
        for i in range(self.num_robots):
            pygame.draw.circle(self.screen, colors[i], (int(self.robot_positions[i][0]), int(self.robot_positions[i][1])), pix_size/2) # Pick the colors from above list

        # Draw infected locations
            for l in self.infected_locations:
                pygame.draw.circle(self.screen, (0, 255, 255), (int(l[0]), int(l[1])), pix_size/2) # Cyan color for infected locations
        
        pygame.display.flip() # Allows only a portion of the screen to be updated
        self.clock.tick(60)
    
    def close(self):
        if self.screen is not None:
            pygame.display.quit()
            pygame.quit()

# %%
# Register environment
gym.register(id='MultiRobotEnv-v0', 
             entry_point=MultiRobotEnv,
             max_episode_steps=1000)

# %%
assert False, "Manual pause"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 assert False, "Manual pause"
#
# AssertionError: Manual pause

# %% [markdown]
# **Training**:

# %%
import stable_baselines3, sb3_contrib
stable_baselines3.__version__, sb3_contrib.__version__
# Out:
# ('2.6.0a1', '2.6.0a1')

# %%
# Experimental settings
weights_path = rf"./new_models/new_{date_n_env}"
tensorboard_log_path = rf"./tensorboard_logs/new_{date_n_env}"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               
time_steps = 1e7

# Import the logger
from stable_baselines3.common.callbacks import LogEveryNTimesteps, EvalCallback, StopTrainingOnNoModelImprovement
logger = LogEveryNTimesteps(n_steps=10000)
# Stop training if there is no improvement after more than 40 evaluations
stop_train_callback = StopTrainingOnNoModelImprovement(max_no_improvement_evals=50, min_evals=5, verbose=1)

# %%
# %%time
from sb3_contrib import TRPO
from stable_baselines3.common.env_util import make_vec_env

vec_env = make_vec_env('MultiRobotEnv-v0', n_envs=4)
eval_env = gym.make('MultiRobotEnv-v0') # Separate evaluation env
eval_callback = EvalCallback(eval_env, eval_freq=50000, callback_after_eval=stop_train_callback, verbose=1)

model = TRPO("MlpPolicy", 
              vec_env, 
              verbose=1, 
              tensorboard_log=tensorboard_log_path+"_trpo")
model.learn(total_timesteps=time_steps, callback=[eval_callback, logger])
model.save(weights_path+"_trpo")
del model, TRPO, make_vec_env, eval_env, eval_callback
# Out:
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 666       |
# |    ep_rew_mean            | -4.71e+04 |
# | time/                     |           |
# |    fps                    | 928       |
# |    time_elapsed           | 990       |
# |    total_timesteps        | 920000    |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00909   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 112       |
# |    policy_objective       | 0.0199    |
# |    std                    | 0.78      |
# |    value_loss             | 1.49e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 688       |
# |    ep_rew_mean     | -1.04e+05 |
# | time/              |           |
# |    fps             | 930       |
# |    iterations      | 113       |
# |    time_elapsed    | 994       |
# |    total_timesteps | 925696    |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 703       |
# |    ep_rew_mean            | -9.94e+04 |
# | time/                     |           |
# |    fps                    | 929       |
# |    time_elapsed           | 1000      |
# |    total_timesteps        | 930000    |
# | train/                    |           |
# |    explained_variance     | -2.38e-07 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00919   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 113       |
# |    policy_objective       | 0.0214    |
# |    std                    | 0.785     |
# |    value_loss             | 1.17e+09  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 704       |
# |    ep_rew_mean     | -9.46e+04 |
# | time/              |           |
# |    fps             | 931       |
# |    iterations      | 114       |
# |    time_elapsed    | 1002      |
# |    total_timesteps | 933888    |
# ----------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 717      |
# |    ep_rew_mean            | -9.2e+04 |
# | time/                     |          |
# |    fps                    | 930      |
# |    time_elapsed           | 1010     |
# |    total_timesteps        | 940000   |
# | train/                    |          |
# |    explained_variance     | 1.19e-07 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00852  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 114      |
# |    policy_objective       | 0.0234   |
# |    std                    | 0.789    |
# |    value_loss             | 1.19e+08 |
# ----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 717       |
# |    ep_rew_mean     | -9.54e+04 |
# | time/              |           |
# |    fps             | 930       |
# |    iterations      | 115       |
# |    time_elapsed    | 1012      |
# |    total_timesteps | 942080    |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 741       |
# |    ep_rew_mean            | -1.08e+05 |
# | time/                     |           |
# |    fps                    | 930       |
# |    time_elapsed           | 1021      |
# |    total_timesteps        | 950000    |
# | train/                    |           |
# |    explained_variance     | 5.96e-08  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00748   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 115       |
# |    policy_objective       | 0.0205    |
# |    std                    | 0.791     |
# |    value_loss             | 9.43e+07  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 741       |
# |    ep_rew_mean     | -1.08e+05 |
# | time/              |           |
# |    fps             | 930       |
# |    iterations      | 116       |
# |    time_elapsed    | 1021      |
# |    total_timesteps | 950272    |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 710       |
# |    ep_rew_mean            | -1.17e+05 |
# | time/                     |           |
# |    fps                    | 930       |
# |    iterations             | 117       |
# |    time_elapsed           | 1030      |
# |    total_timesteps        | 958464    |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.0079    |
# |    learning_rate          | 0.001     |
# |    n_updates              | 116       |
# |    policy_objective       | 0.0185    |
# |    std                    | 0.796     |
# |    value_loss             | 1.78e+08  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 710       |
# |    ep_rew_mean            | -1.17e+05 |
# | time/                     |           |
# |    fps                    | 928       |
# |    time_elapsed           | 1033      |
# |    total_timesteps        | 960000    |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.0085    |
# |    learning_rate          | 0.001     |
# |    n_updates              | 117       |
# |    policy_objective       | 0.0188    |
# |    std                    | 0.799     |
# |    value_loss             | 2.23e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 733       |
# |    ep_rew_mean     | -9.39e+04 |
# | time/              |           |
# |    fps             | 929       |
# |    iterations      | 118       |
# |    time_elapsed    | 1040      |
# |    total_timesteps | 966656    |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 732       |
# |    ep_rew_mean            | -1.02e+05 |
# | time/                     |           |
# |    fps                    | 928       |
# |    time_elapsed           | 1044      |
# |    total_timesteps        | 970000    |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00855   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 118       |
# |    policy_objective       | 0.0334    |
# |    std                    | 0.797     |
# |    value_loss             | 1.61e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 732       |
# |    ep_rew_mean     | -1.05e+05 |
# | time/              |           |
# |    fps             | 929       |
# |    iterations      | 119       |
# |    time_elapsed    | 1048      |
# |    total_timesteps | 974848    |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 733       |
# |    ep_rew_mean            | -1.05e+05 |
# | time/                     |           |
# |    fps                    | 929       |
# |    time_elapsed           | 1054      |
# |    total_timesteps        | 980000    |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00764   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 119       |
# |    policy_objective       | 0.0211    |
# |    std                    | 0.799     |
# |    value_loss             | 1.11e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 725       |
# |    ep_rew_mean     | -1.09e+05 |
# | time/              |           |
# |    fps             | 930       |
# |    iterations      | 120       |
# |    time_elapsed    | 1056      |
# |    total_timesteps | 983040    |
# ----------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 721      |
# |    ep_rew_mean            | -1.1e+05 |
# | time/                     |          |
# |    fps                    | 930      |
# |    time_elapsed           | 1064     |
# |    total_timesteps        | 990000   |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00864  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 120      |
# |    policy_objective       | 0.0204   |
# |    std                    | 0.799    |
# |    value_loss             | 1.51e+08 |
# ----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 710       |
# |    ep_rew_mean     | -1.09e+05 |
# | time/              |           |
# |    fps             | 930       |
# |    iterations      | 121       |
# |    time_elapsed    | 1065      |
# |    total_timesteps | 991232    |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 728       |
# |    ep_rew_mean            | -6.31e+04 |
# | time/                     |           |
# |    fps                    | 930       |
# |    iterations             | 122       |
# |    time_elapsed           | 1074      |
# |    total_timesteps        | 999424    |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00866   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 121       |
# |    policy_objective       | 0.026     |
# |    std                    | 0.799     |
# |    value_loss             | 1.05e+08  |
# -----------------------------------------
# Eval num_timesteps=1000000, episode_reward=19910.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                     |           |
# |    mean_ep_length         | 1e+03     |
# |    mean_reward            | 1.99e+04  |
# | time/                     |           |
# |    total_timesteps        | 1000000   |
# | train/                    |           |
# |    explained_variance     | -1.19e-07 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00779   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 122       |
# |    policy_objective       | 0.0204    |
# |    std                    | 0.802     |
# |    value_loss             | 6.46e+07  |
# -----------------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 728       |
# |    ep_rew_mean     | -6.31e+04 |
# | time/              |           |
# |    fps             | 923       |
# |    time_elapsed    | 1082      |
# |    total_timesteps | 1000000   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 717       |
# |    ep_rew_mean     | -5.94e+04 |
# | time/              |           |
# |    fps             | 925       |
# |    iterations      | 123       |
# |    time_elapsed    | 1088      |
# |    total_timesteps | 1007616   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 715       |
# |    ep_rew_mean            | -5.72e+04 |
# | time/                     |           |
# |    fps                    | 924       |
# |    time_elapsed           | 1092      |
# |    total_timesteps        | 1010000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00834   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 123       |
# |    policy_objective       | 0.0211    |
# |    std                    | 0.802     |
# |    value_loss             | 1.25e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 723       |
# |    ep_rew_mean     | -6.03e+04 |
# | time/              |           |
# |    fps             | 924       |
# |    iterations      | 124       |
# |    time_elapsed    | 1098      |
# |    total_timesteps | 1015808   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 721       |
# |    ep_rew_mean            | -6.28e+04 |
# | time/                     |           |
# |    fps                    | 923       |
# |    time_elapsed           | 1103      |
# |    total_timesteps        | 1020000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00917   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 124       |
# |    policy_objective       | 0.0196    |
# |    std                    | 0.801     |
# |    value_loss             | 1.11e+08  |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 733      |
# |    ep_rew_mean     | -5.5e+04 |
# | time/              |          |
# |    fps             | 924      |
# |    iterations      | 125      |
# |    time_elapsed    | 1107     |
# |    total_timesteps | 1024000  |
# ---------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 747       |
# |    ep_rew_mean            | -4.21e+04 |
# | time/                     |           |
# |    fps                    | 924       |
# |    time_elapsed           | 1113      |
# |    total_timesteps        | 1030000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00888   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 125       |
# |    policy_objective       | 0.0191    |
# |    std                    | 0.803     |
# |    value_loss             | 1.2e+08   |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 758      |
# |    ep_rew_mean     | -3.8e+04 |
# | time/              |          |
# |    fps             | 925      |
# |    iterations      | 126      |
# |    time_elapsed    | 1115     |
# |    total_timesteps | 1032192  |
# ---------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 737       |
# |    ep_rew_mean            | -1.93e+04 |
# | time/                     |           |
# |    fps                    | 925       |
# |    time_elapsed           | 1123      |
# |    total_timesteps        | 1040000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.0079    |
# |    learning_rate          | 0.001     |
# |    n_updates              | 126       |
# |    policy_objective       | 0.0127    |
# |    std                    | 0.796     |
# |    value_loss             | 7.86e+07  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 737       |
# |    ep_rew_mean     | -1.93e+04 |
# | time/              |           |
# |    fps             | 925       |
# |    iterations      | 127       |
# |    time_elapsed    | 1124      |
# |    total_timesteps | 1040384   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 747       |
# |    ep_rew_mean            | -1.07e+04 |
# | time/                     |           |
# |    fps                    | 926       |
# |    iterations             | 128       |
# |    time_elapsed           | 1131      |
# |    total_timesteps        | 1048576   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00794   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 127       |
# |    policy_objective       | 0.0169    |
# |    std                    | 0.794     |
# |    value_loss             | 9.54e+07  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 732       |
# |    ep_rew_mean            | -7.27e+03 |
# | time/                     |           |
# |    fps                    | 925       |
# |    time_elapsed           | 1134      |
# |    total_timesteps        | 1050000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00866   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 128       |
# |    policy_objective       | 0.0198    |
# |    std                    | 0.794     |
# |    value_loss             | 1.08e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 728       |
# |    ep_rew_mean     | -1.49e+03 |
# | time/              |           |
# |    fps             | 926       |
# |    iterations      | 129       |
# |    time_elapsed    | 1140      |
# |    total_timesteps | 1056768   |
# ----------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 719      |
# |    ep_rew_mean            | 6.15e+03 |
# | time/                     |          |
# |    fps                    | 925      |
# |    time_elapsed           | 1144     |
# |    total_timesteps        | 1060000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00777  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 129      |
# |    policy_objective       | 0.0218   |
# |    std                    | 0.794    |
# |    value_loss             | 1.71e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 715      |
# |    ep_rew_mean     | 1.14e+04 |
# | time/              |          |
# |    fps             | 926      |
# |    iterations      | 130      |
# |    time_elapsed    | 1149     |
# |    total_timesteps | 1064960  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 695      |
# |    ep_rew_mean            | 2.19e+04 |
# | time/                     |          |
# |    fps                    | 926      |
# |    time_elapsed           | 1155     |
# |    total_timesteps        | 1070000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00884  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 130      |
# |    policy_objective       | 0.0202   |
# |    std                    | 0.802    |
# |    value_loss             | 1.27e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 709      |
# |    ep_rew_mean     | 2.21e+04 |
# | time/              |          |
# |    fps             | 927      |
# |    iterations      | 131      |
# |    time_elapsed    | 1157     |
# |    total_timesteps | 1073152  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 724      |
# |    ep_rew_mean            | 2.56e+04 |
# | time/                     |          |
# |    fps                    | 926      |
# |    time_elapsed           | 1165     |
# |    total_timesteps        | 1080000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00888  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 131      |
# |    policy_objective       | 0.0207   |
# |    std                    | 0.802    |
# |    value_loss             | 1.06e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 720      |
# |    ep_rew_mean     | 2.68e+04 |
# | time/              |          |
# |    fps             | 927      |
# |    iterations      | 132      |
# |    time_elapsed    | 1166     |
# |    total_timesteps | 1081344  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 708      |
# |    ep_rew_mean            | 3.82e+04 |
# | time/                     |          |
# |    fps                    | 927      |
# |    iterations             | 133      |
# |    time_elapsed           | 1175     |
# |    total_timesteps        | 1089536  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00871  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 132      |
# |    policy_objective       | 0.0246   |
# |    std                    | 0.801    |
# |    value_loss             | 1.45e+08 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 708      |
# |    ep_rew_mean            | 3.82e+04 |
# | time/                     |          |
# |    fps                    | 925      |
# |    time_elapsed           | 1177     |
# |    total_timesteps        | 1090000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00889  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 133      |
# |    policy_objective       | 0.021    |
# |    std                    | 0.802    |
# |    value_loss             | 2.16e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 730      |
# |    ep_rew_mean     | 1.98e+04 |
# | time/              |          |
# |    fps             | 926      |
# |    iterations      | 134      |
# |    time_elapsed    | 1184     |
# |    total_timesteps | 1097728  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 719      |
# |    ep_rew_mean            | 1.92e+04 |
# | time/                     |          |
# |    fps                    | 926      |
# |    time_elapsed           | 1187     |
# |    total_timesteps        | 1100000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0085   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 134      |
# |    policy_objective       | 0.0168   |
# |    std                    | 0.794    |
# |    value_loss             | 1.42e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 726      |
# |    ep_rew_mean     | 1.3e+04  |
# | time/              |          |
# |    fps             | 927      |
# |    iterations      | 135      |
# |    time_elapsed    | 1192     |
# |    total_timesteps | 1105920  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 732      |
# |    ep_rew_mean            | 1.24e+04 |
# | time/                     |          |
# |    fps                    | 927      |
# |    time_elapsed           | 1197     |
# |    total_timesteps        | 1110000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00794  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 135      |
# |    policy_objective       | 0.017    |
# |    std                    | 0.795    |
# |    value_loss             | 1.1e+08  |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 741      |
# |    ep_rew_mean     | 4.13e+03 |
# | time/              |          |
# |    fps             | 927      |
# |    iterations      | 136      |
# |    time_elapsed    | 1201     |
# |    total_timesteps | 1114112  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 744      |
# |    ep_rew_mean            | 3.56e+03 |
# | time/                     |          |
# |    fps                    | 927      |
# |    time_elapsed           | 1207     |
# |    total_timesteps        | 1120000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00866  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 136      |
# |    policy_objective       | 0.0203   |
# |    std                    | 0.789    |
# |    value_loss             | 9.72e+07 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 736      |
# |    ep_rew_mean     | 2.22e+03 |
# | time/              |          |
# |    fps             | 927      |
# |    iterations      | 137      |
# |    time_elapsed    | 1210     |
# |    total_timesteps | 1122304  |
# ---------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 752       |
# |    ep_rew_mean            | -3.82e+03 |
# | time/                     |           |
# |    fps                    | 927       |
# |    time_elapsed           | 1218      |
# |    total_timesteps        | 1130000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00743   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 137       |
# |    policy_objective       | 0.0141    |
# |    std                    | 0.79      |
# |    value_loss             | 8.44e+07  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 749       |
# |    ep_rew_mean     | -3.66e+03 |
# | time/              |           |
# |    fps             | 927       |
# |    iterations      | 138       |
# |    time_elapsed    | 1219      |
# |    total_timesteps | 1130496   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 777       |
# |    ep_rew_mean            | -1.46e+04 |
# | time/                     |           |
# |    fps                    | 927       |
# |    iterations             | 139       |
# |    time_elapsed           | 1228      |
# |    total_timesteps        | 1138688   |
# | train/                    |           |
# |    explained_variance     | -1.19e-07 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00809   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 138       |
# |    policy_objective       | 0.0137    |
# |    std                    | 0.79      |
# |    value_loss             | 1.35e+08  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 783       |
# |    ep_rew_mean            | -1.55e+04 |
# | time/                     |           |
# |    fps                    | 926       |
# |    time_elapsed           | 1231      |
# |    total_timesteps        | 1140000   |
# | train/                    |           |
# |    explained_variance     | 5.96e-08  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00941   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 139       |
# |    policy_objective       | 0.0224    |
# |    std                    | 0.789     |
# |    value_loss             | 1.3e+08   |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 765       |
# |    ep_rew_mean     | -3.92e+04 |
# | time/              |           |
# |    fps             | 926       |
# |    iterations      | 140       |
# |    time_elapsed    | 1237      |
# |    total_timesteps | 1146880   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 762       |
# |    ep_rew_mean            | -3.65e+04 |
# | time/                     |           |
# |    fps                    | 926       |
# |    time_elapsed           | 1241      |
# |    total_timesteps        | 1150000   |
# | train/                    |           |
# |    explained_variance     | -1.19e-07 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00972   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 140       |
# |    policy_objective       | 0.0216    |
# |    std                    | 0.789     |
# |    value_loss             | 4.6e+08   |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 772       |
# |    ep_rew_mean     | -4.15e+04 |
# | time/              |           |
# |    fps             | 926       |
# |    iterations      | 141       |
# |    time_elapsed    | 1246      |
# |    total_timesteps | 1155072   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 782       |
# |    ep_rew_mean            | -4.57e+04 |
# | time/                     |           |
# |    fps                    | 926       |
# |    time_elapsed           | 1252      |
# |    total_timesteps        | 1160000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00856   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 141       |
# |    policy_objective       | 0.0202    |
# |    std                    | 0.787     |
# |    value_loss             | 7.67e+07  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 784       |
# |    ep_rew_mean     | -4.96e+04 |
# | time/              |           |
# |    fps             | 926       |
# |    iterations      | 142       |
# |    time_elapsed    | 1255      |
# |    total_timesteps | 1163264   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 769       |
# |    ep_rew_mean            | -3.42e+04 |
# | time/                     |           |
# |    fps                    | 926       |
# |    time_elapsed           | 1263      |
# |    total_timesteps        | 1170000   |
# | train/                    |           |
# |    explained_variance     | -1.19e-07 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00908   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 142       |
# |    policy_objective       | 0.022     |
# |    std                    | 0.786     |
# |    value_loss             | 8.04e+07  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 770       |
# |    ep_rew_mean     | -2.58e+04 |
# | time/              |           |
# |    fps             | 926       |
# |    iterations      | 143       |
# |    time_elapsed    | 1264      |
# |    total_timesteps | 1171456   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 773       |
# |    ep_rew_mean            | -3.13e+04 |
# | time/                     |           |
# |    fps                    | 926       |
# |    iterations             | 144       |
# |    time_elapsed           | 1273      |
# |    total_timesteps        | 1179648   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.0091    |
# |    learning_rate          | 0.001     |
# |    n_updates              | 143       |
# |    policy_objective       | 0.0145    |
# |    std                    | 0.782     |
# |    value_loss             | 1.18e+08  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 773       |
# |    ep_rew_mean            | -3.13e+04 |
# | time/                     |           |
# |    fps                    | 925       |
# |    time_elapsed           | 1275      |
# |    total_timesteps        | 1180000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00781   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 144       |
# |    policy_objective       | 0.0197    |
# |    std                    | 0.783     |
# |    value_loss             | 1.65e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 771       |
# |    ep_rew_mean     | -3.43e+04 |
# | time/              |           |
# |    fps             | 926       |
# |    iterations      | 145       |
# |    time_elapsed    | 1282      |
# |    total_timesteps | 1187840   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 765       |
# |    ep_rew_mean            | -3.36e+04 |
# | time/                     |           |
# |    fps                    | 925       |
# |    time_elapsed           | 1285      |
# |    total_timesteps        | 1190000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00785   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 145       |
# |    policy_objective       | 0.0189    |
# |    std                    | 0.779     |
# |    value_loss             | 7.95e+07  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 747       |
# |    ep_rew_mean     | -2.86e+04 |
# | time/              |           |
# |    fps             | 926       |
# |    iterations      | 146       |
# |    time_elapsed    | 1291      |
# |    total_timesteps | 1196032   |
# ----------------------------------
# Eval num_timesteps=1200000, episode_reward=-60810.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# -----------------------------------------
# | eval/                     |           |
# |    mean_ep_length         | 1e+03     |
# |    mean_reward            | -6.08e+04 |
# | time/                     |           |
# |    total_timesteps        | 1200000   |
# | train/                    |           |
# |    explained_variance     | -1.19e-07 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00869   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 146       |
# |    policy_objective       | 0.0171    |
# |    std                    | 0.772     |
# |    value_loss             | 9.44e+07  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 751       |
# |    ep_rew_mean     | -3.02e+04 |
# | time/              |           |
# |    fps             | 920       |
# |    time_elapsed    | 1304      |
# |    total_timesteps | 1200000   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 776       |
# |    ep_rew_mean     | -3.73e+04 |
# | time/              |           |
# |    fps             | 920       |
# |    iterations      | 147       |
# |    time_elapsed    | 1308      |
# |    total_timesteps | 1204224   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 760       |
# |    ep_rew_mean            | -4.51e+04 |
# | time/                     |           |
# |    fps                    | 920       |
# |    time_elapsed           | 1314      |
# |    total_timesteps        | 1210000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.0087    |
# |    learning_rate          | 0.001     |
# |    n_updates              | 147       |
# |    policy_objective       | 0.0238    |
# |    std                    | 0.773     |
# |    value_loss             | 6.34e+07  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 753       |
# |    ep_rew_mean     | -4.21e+04 |
# | time/              |           |
# |    fps             | 920       |
# |    iterations      | 148       |
# |    time_elapsed    | 1316      |
# |    total_timesteps | 1212416   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 760       |
# |    ep_rew_mean            | -5.77e+04 |
# | time/                     |           |
# |    fps                    | 921       |
# |    time_elapsed           | 1323      |
# |    total_timesteps        | 1220000   |
# | train/                    |           |
# |    explained_variance     | 5.96e-08  |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00847   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 148       |
# |    policy_objective       | 0.023     |
# |    std                    | 0.775     |
# |    value_loss             | 2.04e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 760       |
# |    ep_rew_mean     | -5.77e+04 |
# | time/              |           |
# |    fps             | 921       |
# |    iterations      | 149       |
# |    time_elapsed    | 1324      |
# |    total_timesteps | 1220608   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 766       |
# |    ep_rew_mean            | -4.16e+04 |
# | time/                     |           |
# |    fps                    | 921       |
# |    iterations             | 150       |
# |    time_elapsed           | 1333      |
# |    total_timesteps        | 1228800   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00777   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 149       |
# |    policy_objective       | 0.0192    |
# |    std                    | 0.768     |
# |    value_loss             | 2.64e+08  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 758       |
# |    ep_rew_mean            | -4.18e+04 |
# | time/                     |           |
# |    fps                    | 920       |
# |    time_elapsed           | 1336      |
# |    total_timesteps        | 1230000   |
# | train/                    |           |
# |    explained_variance     | -1.19e-07 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00836   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 150       |
# |    policy_objective       | 0.0231    |
# |    std                    | 0.767     |
# |    value_loss             | 1.44e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 746       |
# |    ep_rew_mean     | -5.39e+04 |
# | time/              |           |
# |    fps             | 921       |
# |    iterations      | 151       |
# |    time_elapsed    | 1342      |
# |    total_timesteps | 1236992   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 759       |
# |    ep_rew_mean            | -5.58e+04 |
# | time/                     |           |
# |    fps                    | 920       |
# |    time_elapsed           | 1346      |
# |    total_timesteps        | 1240000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00811   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 151       |
# |    policy_objective       | 0.0103    |
# |    std                    | 0.761     |
# |    value_loss             | 3.58e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 768       |
# |    ep_rew_mean     | -6.08e+04 |
# | time/              |           |
# |    fps             | 921       |
# |    iterations      | 152       |
# |    time_elapsed    | 1351      |
# |    total_timesteps | 1245184   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 775       |
# |    ep_rew_mean            | -7.88e+04 |
# | time/                     |           |
# |    fps                    | 920       |
# |    time_elapsed           | 1357      |
# |    total_timesteps        | 1250000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00756   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 152       |
# |    policy_objective       | 0.0215    |
# |    std                    | 0.762     |
# |    value_loss             | 2.01e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 778       |
# |    ep_rew_mean     | -7.55e+04 |
# | time/              |           |
# |    fps             | 921       |
# |    iterations      | 153       |
# |    time_elapsed    | 1360      |
# |    total_timesteps | 1253376   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 756       |
# |    ep_rew_mean            | -7.98e+04 |
# | time/                     |           |
# |    fps                    | 921       |
# |    time_elapsed           | 1367      |
# |    total_timesteps        | 1260000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00882   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 153       |
# |    policy_objective       | 0.0178    |
# |    std                    | 0.76      |
# |    value_loss             | 1.28e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 756       |
# |    ep_rew_mean     | -8.05e+04 |
# | time/              |           |
# |    fps             | 921       |
# |    iterations      | 154       |
# |    time_elapsed    | 1369      |
# |    total_timesteps | 1261568   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 770       |
# |    ep_rew_mean            | -8.13e+04 |
# | time/                     |           |
# |    fps                    | 921       |
# |    iterations             | 155       |
# |    time_elapsed           | 1378      |
# |    total_timesteps        | 1269760   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.0094    |
# |    learning_rate          | 0.001     |
# |    n_updates              | 154       |
# |    policy_objective       | 0.0249    |
# |    std                    | 0.758     |
# |    value_loss             | 6.04e+08  |
# -----------------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 769       |
# |    ep_rew_mean            | -8.09e+04 |
# | time/                     |           |
# |    fps                    | 920       |
# |    time_elapsed           | 1380      |
# |    total_timesteps        | 1270000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00848   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 155       |
# |    policy_objective       | 0.0198    |
# |    std                    | 0.759     |
# |    value_loss             | 1.06e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 723       |
# |    ep_rew_mean     | -7.32e+04 |
# | time/              |           |
# |    fps             | 921       |
# |    iterations      | 156       |
# |    time_elapsed    | 1387      |
# |    total_timesteps | 1277952   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 720       |
# |    ep_rew_mean            | -7.24e+04 |
# | time/                     |           |
# |    fps                    | 920       |
# |    time_elapsed           | 1390      |
# |    total_timesteps        | 1280000   |
# | train/                    |           |
# |    explained_variance     | 0         |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00822   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 156       |
# |    policy_objective       | 0.0253    |
# |    std                    | 0.757     |
# |    value_loss             | 2.29e+08  |
# -----------------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 728       |
# |    ep_rew_mean     | -6.69e+04 |
# | time/              |           |
# |    fps             | 921       |
# |    iterations      | 157       |
# |    time_elapsed    | 1395      |
# |    total_timesteps | 1286144   |
# ----------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 719       |
# |    ep_rew_mean            | -4.99e+04 |
# | time/                     |           |
# |    fps                    | 920       |
# ...
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 323      |
# |    ep_rew_mean            | 1.36e+05 |
# | time/                     |          |
# |    fps                    | 913      |
# |    time_elapsed           | 10810    |
# |    total_timesteps        | 9880000  |
# | train/                    |          |
# |    explained_variance     | 5.96e-08 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0091   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1206     |
# |    policy_objective       | 0.0304   |
# |    std                    | 0.655    |
# |    value_loss             | 2.47e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 320      |
# |    ep_rew_mean     | 1.33e+05 |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1207     |
# |    time_elapsed    | 10816    |
# |    total_timesteps | 9887744  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 303      |
# |    ep_rew_mean            | 1.31e+05 |
# | time/                     |          |
# |    fps                    | 914      |
# |    time_elapsed           | 10820    |
# |    total_timesteps        | 9890000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00959  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1207     |
# |    policy_objective       | 0.0224   |
# |    std                    | 0.655    |
# |    value_loss             | 2.11e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 306      |
# |    ep_rew_mean     | 1.29e+05 |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1208     |
# |    time_elapsed    | 10825    |
# |    total_timesteps | 9895936  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 298      |
# |    ep_rew_mean            | 1.29e+05 |
# | time/                     |          |
# |    fps                    | 914      |
# |    time_elapsed           | 10830    |
# |    total_timesteps        | 9900000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00665  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1208     |
# |    policy_objective       | 0.0147   |
# |    std                    | 0.655    |
# |    value_loss             | 2.61e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 293      |
# |    ep_rew_mean     | 1.28e+05 |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1209     |
# |    time_elapsed    | 10834    |
# |    total_timesteps | 9904128  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 307      |
# |    ep_rew_mean            | 1.27e+05 |
# | time/                     |          |
# |    fps                    | 914      |
# |    time_elapsed           | 10840    |
# |    total_timesteps        | 9910000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00956  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1209     |
# |    policy_objective       | 0.0274   |
# |    std                    | 0.656    |
# |    value_loss             | 2.11e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 304      |
# |    ep_rew_mean     | 1.27e+05 |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1210     |
# |    time_elapsed    | 10842    |
# |    total_timesteps | 9912320  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 308      |
# |    ep_rew_mean            | 1.33e+05 |
# | time/                     |          |
# |    fps                    | 914      |
# |    time_elapsed           | 10850    |
# |    total_timesteps        | 9920000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00956  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1210     |
# |    policy_objective       | 0.0212   |
# |    std                    | 0.656    |
# |    value_loss             | 2.16e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 309      |
# |    ep_rew_mean     | 1.33e+05 |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1211     |
# |    time_elapsed    | 10851    |
# |    total_timesteps | 9920512  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 314      |
# |    ep_rew_mean            | 1.36e+05 |
# | time/                     |          |
# |    fps                    | 914      |
# |    iterations             | 1212     |
# |    time_elapsed           | 10860    |
# |    total_timesteps        | 9928704  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00895  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1211     |
# |    policy_objective       | 0.019    |
# |    std                    | 0.656    |
# |    value_loss             | 2.07e+08 |
# ----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 310      |
# |    ep_rew_mean            | 1.37e+05 |
# | time/                     |          |
# |    fps                    | 914      |
# |    time_elapsed           | 10862    |
# |    total_timesteps        | 9930000  |
# | train/                    |          |
# |    explained_variance     | 5.96e-08 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00647  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1212     |
# |    policy_objective       | 0.0178   |
# |    std                    | 0.656    |
# |    value_loss             | 2.19e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 305      |
# |    ep_rew_mean     | 1.39e+05 |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1213     |
# |    time_elapsed    | 10869    |
# |    total_timesteps | 9936896  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 303      |
# |    ep_rew_mean            | 1.39e+05 |
# | time/                     |          |
# |    fps                    | 914      |
# |    time_elapsed           | 10873    |
# |    total_timesteps        | 9940000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00949  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1213     |
# |    policy_objective       | 0.0294   |
# |    std                    | 0.656    |
# |    value_loss             | 2.14e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 305      |
# |    ep_rew_mean     | 1.39e+05 |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1214     |
# |    time_elapsed    | 10877    |
# |    total_timesteps | 9945088  |
# ---------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 305       |
# |    ep_rew_mean            | 1.39e+05  |
# | time/                     |           |
# |    fps                    | 914       |
# |    time_elapsed           | 10883     |
# |    total_timesteps        | 9950000   |
# | train/                    |           |
# |    explained_variance     | -1.19e-07 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00943   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 1214      |
# |    policy_objective       | 0.0183    |
# |    std                    | 0.656     |
# |    value_loss             | 2.26e+08  |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 295      |
# |    ep_rew_mean     | 1.4e+05  |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1215     |
# |    time_elapsed    | 10886    |
# |    total_timesteps | 9953280  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 280      |
# |    ep_rew_mean            | 1.4e+05  |
# | time/                     |          |
# |    fps                    | 914      |
# |    time_elapsed           | 10893    |
# |    total_timesteps        | 9960000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00985  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1215     |
# |    policy_objective       | 0.0241   |
# |    std                    | 0.656    |
# |    value_loss             | 2.23e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 288      |
# |    ep_rew_mean     | 1.4e+05  |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1216     |
# |    time_elapsed    | 10895    |
# |    total_timesteps | 9961472  |
# ---------------------------------
# -----------------------------------------
# | rollout/                  |           |
# |    ep_len_mean            | 305       |
# |    ep_rew_mean            | 1.39e+05  |
# | time/                     |           |
# |    fps                    | 914       |
# |    iterations             | 1217      |
# |    time_elapsed           | 10903     |
# |    total_timesteps        | 9969664   |
# | train/                    |           |
# |    explained_variance     | -1.19e-07 |
# |    is_line_search_success | 1         |
# |    kl_divergence_loss     | 0.00979   |
# |    learning_rate          | 0.001     |
# |    n_updates              | 1216      |
# |    policy_objective       | 0.0235    |
# |    std                    | 0.656     |
# |    value_loss             | 2.26e+08  |
# -----------------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 305      |
# |    ep_rew_mean            | 1.39e+05 |
# | time/                     |          |
# |    fps                    | 914      |
# |    time_elapsed           | 10905    |
# |    total_timesteps        | 9970000  |
# | train/                    |          |
# |    explained_variance     | 5.96e-08 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00953  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1217     |
# |    policy_objective       | 0.023    |
# |    std                    | 0.656    |
# |    value_loss             | 2.03e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 304      |
# |    ep_rew_mean     | 1.39e+05 |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1218     |
# |    time_elapsed    | 10911    |
# |    total_timesteps | 9977856  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 305      |
# |    ep_rew_mean            | 1.37e+05 |
# | time/                     |          |
# |    fps                    | 914      |
# |    time_elapsed           | 10915    |
# |    total_timesteps        | 9980000  |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.0065   |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1218     |
# |    policy_objective       | 0.0136   |
# |    std                    | 0.657    |
# |    value_loss             | 2.2e+08  |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 309      |
# |    ep_rew_mean     | 1.35e+05 |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1219     |
# |    time_elapsed    | 10920    |
# |    total_timesteps | 9986048  |
# ---------------------------------
# ----------------------------------------
# | rollout/                  |          |
# |    ep_len_mean            | 305      |
# |    ep_rew_mean            | 1.33e+05 |
# | time/                     |          |
# |    fps                    | 914      |
# |    time_elapsed           | 10926    |
# |    total_timesteps        | 9990000  |
# | train/                    |          |
# |    explained_variance     | 5.96e-08 |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00987  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1219     |
# |    policy_objective       | 0.0235   |
# |    std                    | 0.657    |
# |    value_loss             | 2.47e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 292      |
# |    ep_rew_mean     | 1.33e+05 |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1220     |
# |    time_elapsed    | 10930    |
# |    total_timesteps | 9994240  |
# ---------------------------------
# Eval num_timesteps=10000000, episode_reward=134080.00 +/- 0.00
# Episode length: 287.00 +/- 0.00
# ----------------------------------------
# | eval/                     |          |
# |    mean_ep_length         | 287      |
# |    mean_reward            | 1.34e+05 |
# | time/                     |          |
# |    total_timesteps        | 10000000 |
# | train/                    |          |
# |    explained_variance     | 0        |
# |    is_line_search_success | 1        |
# |    kl_divergence_loss     | 0.00957  |
# |    learning_rate          | 0.001    |
# |    n_updates              | 1220     |
# |    policy_objective       | 0.0171   |
# |    std                    | 0.656    |
# |    value_loss             | 2.53e+08 |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 290      |
# |    ep_rew_mean     | 1.33e+05 |
# | time/              |          |
# |    fps             | 914      |
# |    time_elapsed    | 10938    |
# |    total_timesteps | 10000000 |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 292      |
# |    ep_rew_mean     | 1.34e+05 |
# | time/              |          |
# |    fps             | 914      |
# |    iterations      | 1221     |
# |    time_elapsed    | 10941    |
# |    total_timesteps | 10002432 |
# ---------------------------------
# CPU times: total: 3h 1min 29s
# Wall time: 3h 2min 25s

# %%
# %%time
from stable_baselines3.common.env_util import make_vec_env # for making environments
from sb3_contrib import CrossQ

vec_env = make_vec_env('MultiRobotEnv-v0', n_envs=4)
eval_env = gym.make('MultiRobotEnv-v0') # Separate evaluation env
eval_callback = EvalCallback(eval_env, eval_freq=50000, callback_after_eval=stop_train_callback, verbose=1)

model = CrossQ("MlpPolicy", 
            vec_env, 
            verbose=1, 
            tensorboard_log=tensorboard_log_path+"_CrossQ")
model.learn(total_timesteps=time_steps, callback=[eval_callback, logger])
model.save(weights_path+"_CrossQ")
del model, CrossQ, make_vec_env, eval_env, eval_callback
# Out:
# Using cuda device
# Logging to ./tensorboard_logs/new_apr11_env1_double_CrossQ\CrossQ_1
# c:\Users\choton\miniconda3\envs\rl4pag\Lib\site-packages\gymnasium\spaces\box.py:235: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 292       |
# |    ep_rew_mean     | -1.16e+06 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 178       |
# |    time_elapsed    | 12        |
# |    total_timesteps | 2284      |
# | train/             |           |
# |    actor_loss      | -559      |
# |    critic_loss     | 3.03e+07  |
# |    ent_coef        | 1.14      |
# |    ent_coef_loss   | -0.987    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 545       |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 365       |
# |    ep_rew_mean     | -1.24e+06 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 174       |
# |    time_elapsed    | 23        |
# |    total_timesteps | 4172      |
# | train/             |           |
# |    actor_loss      | -136      |
# |    critic_loss     | 1.14e+07  |
# |    ent_coef        | 1.43      |
# |    ent_coef_loss   | -3.34     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1017      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 445       |
# |    ep_rew_mean     | -1.35e+06 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 172       |
# |    time_elapsed    | 37        |
# |    total_timesteps | 6528      |
# | train/             |           |
# |    actor_loss      | 1.09e+03  |
# |    critic_loss     | 6.13e+06  |
# |    ent_coef        | 1.79      |
# |    ent_coef_loss   | -5.16     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1606      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 449       |
# |    ep_rew_mean     | -1.08e+06 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 172       |
# |    time_elapsed    | 47        |
# |    total_timesteps | 8120      |
# | train/             |           |
# |    actor_loss      | 1.29e+03  |
# |    critic_loss     | 6.93e+06  |
# |    ent_coef        | 2.05      |
# |    ent_coef_loss   | -7.4      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2004      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 451       |
# |    ep_rew_mean     | -9.09e+05 |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 172       |
# |    time_elapsed    | 60        |
# |    total_timesteps | 10396     |
# | train/             |           |
# |    actor_loss      | 2.76e+03  |
# |    critic_loss     | 4.65e+06  |
# |    ent_coef        | 2.49      |
# |    ent_coef_loss   | -8.39     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2573      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 456       |
# |    ep_rew_mean     | -7.73e+05 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 172       |
# |    time_elapsed    | 65        |
# |    total_timesteps | 11296     |
# | train/             |           |
# |    actor_loss      | 2.48e+03  |
# |    critic_loss     | 3.01e+06  |
# |    ent_coef        | 2.67      |
# |    ent_coef_loss   | -8.23     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2798      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 440       |
# |    ep_rew_mean     | -6.84e+05 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 171       |
# |    time_elapsed    | 79        |
# |    total_timesteps | 13648     |
# | train/             |           |
# |    actor_loss      | 2.51e+03  |
# |    critic_loss     | 5.11e+07  |
# |    ent_coef        | 3.18      |
# |    ent_coef_loss   | -10.2     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3386      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 399       |
# |    ep_rew_mean     | -6.16e+05 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 171       |
# |    time_elapsed    | 84        |
# |    total_timesteps | 14564     |
# | train/             |           |
# |    actor_loss      | 2.67e+03  |
# |    critic_loss     | 3.85e+07  |
# |    ent_coef        | 3.42      |
# |    ent_coef_loss   | -10.2     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3615      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 410       |
# |    ep_rew_mean     | -5.61e+05 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 171       |
# |    time_elapsed    | 90        |
# |    total_timesteps | 15524     |
# | train/             |           |
# |    actor_loss      | 2.8e+03   |
# |    critic_loss     | 3.46e+06  |
# |    ent_coef        | 3.71      |
# |    ent_coef_loss   | -13       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3855      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 406       |
# |    ep_rew_mean     | -5.16e+05 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 171       |
# |    time_elapsed    | 102       |
# |    total_timesteps | 17556     |
# | train/             |           |
# |    actor_loss      | 3.74e+03  |
# |    critic_loss     | 6.18e+07  |
# |    ent_coef        | 4.41      |
# |    ent_coef_loss   | -13.3     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4363      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 405       |
# |    ep_rew_mean     | -4.76e+05 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 171       |
# |    time_elapsed    | 105       |
# |    total_timesteps | 18140     |
# | train/             |           |
# |    actor_loss      | 3.67e+03  |
# |    critic_loss     | 6e+06     |
# |    ent_coef        | 4.63      |
# |    ent_coef_loss   | -14.6     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4509      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 386       |
# |    ep_rew_mean     | -4.46e+05 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 171       |
# |    time_elapsed    | 112       |
# |    total_timesteps | 19268     |
# | train/             |           |
# |    actor_loss      | 4.05e+03  |
# |    critic_loss     | 2.28e+07  |
# |    ent_coef        | 5.06      |
# |    ent_coef_loss   | -12.5     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 4791      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 380      |
# |    ep_rew_mean     | -4.2e+05 |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 171      |
# |    time_elapsed    | 120      |
# |    total_timesteps | 20624    |
# | train/             |          |
# |    actor_loss      | 3.85e+03 |
# |    critic_loss     | 7.89e+07 |
# |    ent_coef        | 5.59     |
# |    ent_coef_loss   | -13.8    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5130     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 370       |
# |    ep_rew_mean     | -3.98e+05 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 170       |
# |    time_elapsed    | 125       |
# |    total_timesteps | 21400     |
# | train/             |           |
# |    actor_loss      | 2.71e+03  |
# |    critic_loss     | 2.22e+07  |
# |    ent_coef        | 5.92      |
# |    ent_coef_loss   | -15       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 5324      |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 371      |
# |    ep_rew_mean     | -3.8e+05 |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 171      |
# |    time_elapsed    | 134      |
# |    total_timesteps | 22944    |
# | train/             |          |
# |    actor_loss      | 3.84e+03 |
# |    critic_loss     | 6.12e+07 |
# |    ent_coef        | 6.64     |
# |    ent_coef_loss   | -13.4    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5710     |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 373       |
# |    ep_rew_mean     | -3.61e+05 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 170       |
# |    time_elapsed    | 142       |
# |    total_timesteps | 24292     |
# | train/             |           |
# |    actor_loss      | 3.58e+03  |
# |    critic_loss     | 3.63e+06  |
# |    ent_coef        | 7.32      |
# |    ent_coef_loss   | -14.7     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6047      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 365       |
# |    ep_rew_mean     | -3.44e+05 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 170       |
# |    time_elapsed    | 151       |
# |    total_timesteps | 25980     |
# | train/             |           |
# |    actor_loss      | 3.84e+03  |
# |    critic_loss     | 4.28e+06  |
# |    ent_coef        | 8.18      |
# |    ent_coef_loss   | -13.4     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 6469      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 382       |
# |    ep_rew_mean     | -3.33e+05 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 171       |
# |    time_elapsed    | 165       |
# |    total_timesteps | 28396     |
# | train/             |           |
# |    actor_loss      | 4.94e+03  |
# |    critic_loss     | 3.26e+07  |
# |    ent_coef        | 9.49      |
# |    ent_coef_loss   | -12.4     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7073      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 382       |
# |    ep_rew_mean     | -3.22e+05 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 171       |
# |    time_elapsed    | 172       |
# |    total_timesteps | 29576     |
# | train/             |           |
# |    actor_loss      | 3.74e+03  |
# |    critic_loss     | 6.12e+07  |
# |    ent_coef        | 10.2      |
# |    ent_coef_loss   | -12       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7368      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 380       |
# |    ep_rew_mean     | -3.12e+05 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 171       |
# |    time_elapsed    | 186       |
# |    total_timesteps | 31968     |
# | train/             |           |
# |    actor_loss      | 4.9e+03   |
# |    critic_loss     | 6.71e+07  |
# |    ent_coef        | 11.6      |
# |    ent_coef_loss   | -11.8     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7966      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 385       |
# |    ep_rew_mean     | -3.03e+05 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 170       |
# |    time_elapsed    | 191       |
# |    total_timesteps | 32716     |
# | train/             |           |
# |    actor_loss      | 4.68e+03  |
# |    critic_loss     | 4.16e+06  |
# |    ent_coef        | 12.1      |
# |    ent_coef_loss   | -8.89     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8153      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 380       |
# |    ep_rew_mean     | -2.94e+05 |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 171       |
# |    time_elapsed    | 205       |
# |    total_timesteps | 35116     |
# | train/             |           |
# |    actor_loss      | 5.42e+03  |
# |    critic_loss     | 3.34e+07  |
# |    ent_coef        | 13.6      |
# |    ent_coef_loss   | -11.8     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8753      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 380       |
# |    ep_rew_mean     | -2.87e+05 |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 171       |
# |    time_elapsed    | 214       |
# |    total_timesteps | 36732     |
# | train/             |           |
# |    actor_loss      | 5.19e+03  |
# |    critic_loss     | 5.52e+06  |
# |    ent_coef        | 14.8      |
# |    ent_coef_loss   | -11.9     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9157      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 387       |
# |    ep_rew_mean     | -2.79e+05 |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 171       |
# |    time_elapsed    | 218       |
# |    total_timesteps | 37416     |
# | train/             |           |
# |    actor_loss      | 4.53e+03  |
# |    critic_loss     | 2.41e+06  |
# |    ent_coef        | 15.4      |
# |    ent_coef_loss   | -8.78     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9328      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 398       |
# |    ep_rew_mean     | -2.71e+05 |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 171       |
# |    time_elapsed    | 239       |
# |    total_timesteps | 40976     |
# | train/             |           |
# |    actor_loss      | 4.07e+03  |
# |    critic_loss     | 8.44e+06  |
# |    ent_coef        | 18.1      |
# |    ent_coef_loss   | -8.01     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10218     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 399       |
# |    ep_rew_mean     | -2.34e+05 |
# | time/              |           |
# |    episodes        | 104       |
# |    fps             | 171       |
# |    time_elapsed    | 243       |
# |    total_timesteps | 41784     |
# | train/             |           |
# |    actor_loss      | 3.85e+03  |
# |    critic_loss     | 3.19e+06  |
# |    ent_coef        | 18.7      |
# |    ent_coef_loss   | -7.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10420     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 398       |
# |    ep_rew_mean     | -1.97e+05 |
# | time/              |           |
# |    episodes        | 108       |
# |    fps             | 171       |
# |    time_elapsed    | 254       |
# |    total_timesteps | 43584     |
# | train/             |           |
# |    actor_loss      | 4.47e+03  |
# |    critic_loss     | 4.25e+07  |
# |    ent_coef        | 20.2      |
# |    ent_coef_loss   | -8.26     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10870     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 385       |
# |    ep_rew_mean     | -1.38e+05 |
# | time/              |           |
# |    episodes        | 112       |
# |    fps             | 171       |
# |    time_elapsed    | 262       |
# |    total_timesteps | 44984     |
# | train/             |           |
# |    actor_loss      | 4.32e+03  |
# |    critic_loss     | 4.96e+07  |
# |    ent_coef        | 21.4      |
# |    ent_coef_loss   | -8.27     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11220     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 384       |
# |    ep_rew_mean     | -1.27e+05 |
# | time/              |           |
# |    episodes        | 116       |
# |    fps             | 171       |
# |    time_elapsed    | 271       |
# |    total_timesteps | 46540     |
# | train/             |           |
# |    actor_loss      | 5.38e+03  |
# |    critic_loss     | 8.3e+06   |
# |    ent_coef        | 22.8      |
# |    ent_coef_loss   | -5.82     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11609     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 392      |
# |    ep_rew_mean     | -1.2e+05 |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 171      |
# |    time_elapsed    | 286      |
# |    total_timesteps | 48984    |
# | train/             |          |
# |    actor_loss      | 5.76e+03 |
# |    critic_loss     | 5.27e+07 |
# |    ent_coef        | 24.9     |
# |    ent_coef_loss   | -6.76    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12220    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 391      |
# |    ep_rew_mean     | -1.2e+05 |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 171      |
# |    time_elapsed    | 301      |
# |    total_timesteps | 51680    |
# | train/             |          |
# |    actor_loss      | 6.5e+03  |
# |    critic_loss     | 3.25e+06 |
# |    ent_coef        | 27.5     |
# |    ent_coef_loss   | -4.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 12894    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 399       |
# |    ep_rew_mean     | -1.19e+05 |
# | time/              |           |
# |    episodes        | 128       |
# |    fps             | 171       |
# |    time_elapsed    | 316       |
# |    total_timesteps | 54288     |
# | train/             |           |
# |    actor_loss      | 5.87e+03  |
# |    critic_loss     | 4.12e+06  |
# |    ent_coef        | 29.9      |
# |    ent_coef_loss   | -5.1      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13546     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 414       |
# |    ep_rew_mean     | -1.17e+05 |
# | time/              |           |
# |    episodes        | 132       |
# |    fps             | 171       |
# |    time_elapsed    | 321       |
# |    total_timesteps | 55152     |
# | train/             |           |
# |    actor_loss      | 5.16e+03  |
# |    critic_loss     | 5.33e+07  |
# |    ent_coef        | 30.7      |
# |    ent_coef_loss   | -4.96     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13762     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 419       |
# |    ep_rew_mean     | -1.13e+05 |
# | time/              |           |
# |    episodes        | 136       |
# |    fps             | 171       |
# |    time_elapsed    | 341       |
# |    total_timesteps | 58520     |
# | train/             |           |
# |    actor_loss      | 6.6e+03   |
# |    critic_loss     | 3.83e+07  |
# |    ent_coef        | 33.5      |
# |    ent_coef_loss   | -3.16     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14604     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 429       |
# |    ep_rew_mean     | -1.12e+05 |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 171       |
# |    time_elapsed    | 353       |
# |    total_timesteps | 60636     |
# | train/             |           |
# |    actor_loss      | 7.43e+03  |
# |    critic_loss     | 4.7e+06   |
# |    ent_coef        | 35.1      |
# |    ent_coef_loss   | -1.15     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15133     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 436       |
# |    ep_rew_mean     | -1.17e+05 |
# | time/              |           |
# |    episodes        | 144       |
# |    fps             | 171       |
# |    time_elapsed    | 361       |
# |    total_timesteps | 62060     |
# | train/             |           |
# |    actor_loss      | 8.09e+03  |
# |    critic_loss     | 2.76e+07  |
# |    ent_coef        | 36        |
# |    ent_coef_loss   | -1.46     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15489     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 438       |
# |    ep_rew_mean     | -1.16e+05 |
# | time/              |           |
# |    episodes        | 148       |
# |    fps             | 171       |
# |    time_elapsed    | 374       |
# |    total_timesteps | 64208     |
# | train/             |           |
# |    actor_loss      | 8.56e+03  |
# |    critic_loss     | 5.26e+07  |
# |    ent_coef        | 37.6      |
# |    ent_coef_loss   | -2.49     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16026     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 442       |
# |    ep_rew_mean     | -1.15e+05 |
# | time/              |           |
# |    episodes        | 152       |
# |    fps             | 171       |
# |    time_elapsed    | 379       |
# |    total_timesteps | 65100     |
# | train/             |           |
# |    actor_loss      | 7.89e+03  |
# |    critic_loss     | 4.24e+06  |
# |    ent_coef        | 38.3      |
# |    ent_coef_loss   | -0.996    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16249     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 444       |
# |    ep_rew_mean     | -1.13e+05 |
# | time/              |           |
# |    episodes        | 156       |
# |    fps             | 171       |
# |    time_elapsed    | 382       |
# |    total_timesteps | 65612     |
# | train/             |           |
# |    actor_loss      | 8.27e+03  |
# |    critic_loss     | 3.5e+07   |
# |    ent_coef        | 38.5      |
# |    ent_coef_loss   | 0.196     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16377     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 437       |
# |    ep_rew_mean     | -1.12e+05 |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 171       |
# |    time_elapsed    | 391       |
# |    total_timesteps | 67128     |
# | train/             |           |
# |    actor_loss      | 7.09e+03  |
# |    critic_loss     | 4.02e+06  |
# |    ent_coef        | 38.4      |
# |    ent_coef_loss   | -1.43     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16756     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 444       |
# |    ep_rew_mean     | -1.12e+05 |
# | time/              |           |
# |    episodes        | 164       |
# |    fps             | 171       |
# |    time_elapsed    | 400       |
# |    total_timesteps | 68552     |
# | train/             |           |
# |    actor_loss      | 6.92e+03  |
# |    critic_loss     | 1.26e+07  |
# |    ent_coef        | 38.9      |
# |    ent_coef_loss   | -0.414    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17112     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 444       |
# |    ep_rew_mean     | -1.11e+05 |
# | time/              |           |
# |    episodes        | 168       |
# |    fps             | 171       |
# |    time_elapsed    | 409       |
# |    total_timesteps | 70112     |
# | train/             |           |
# |    actor_loss      | 8.09e+03  |
# |    critic_loss     | 5.01e+06  |
# |    ent_coef        | 38.8      |
# |    ent_coef_loss   | 0.894     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17502     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 440       |
# |    ep_rew_mean     | -1.08e+05 |
# | time/              |           |
# |    episodes        | 172       |
# |    fps             | 171       |
# |    time_elapsed    | 423       |
# |    total_timesteps | 72476     |
# | train/             |           |
# |    actor_loss      | 8.35e+03  |
# |    critic_loss     | 2.42e+07  |
# |    ent_coef        | 38.4      |
# |    ent_coef_loss   | 1.31      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18093     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 433       |
# |    ep_rew_mean     | -1.07e+05 |
# | time/              |           |
# |    episodes        | 176       |
# |    fps             | 171       |
# |    time_elapsed    | 428       |
# |    total_timesteps | 73448     |
# | train/             |           |
# |    actor_loss      | 8.54e+03  |
# |    critic_loss     | 2.88e+07  |
# |    ent_coef        | 38        |
# |    ent_coef_loss   | 1.77      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18336     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 438       |
# |    ep_rew_mean     | -1.05e+05 |
# | time/              |           |
# |    episodes        | 180       |
# |    fps             | 171       |
# |    time_elapsed    | 438       |
# |    total_timesteps | 75096     |
# | train/             |           |
# |    actor_loss      | 7.88e+03  |
# |    critic_loss     | 1.31e+07  |
# |    ent_coef        | 37.7      |
# |    ent_coef_loss   | -1.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18748     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 429       |
# |    ep_rew_mean     | -1.04e+05 |
# | time/              |           |
# |    episodes        | 184       |
# |    fps             | 171       |
# |    time_elapsed    | 446       |
# |    total_timesteps | 76364     |
# | train/             |           |
# |    actor_loss      | 7.98e+03  |
# |    critic_loss     | 4.8e+06   |
# |    ent_coef        | 38.1      |
# |    ent_coef_loss   | -1.71     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19065     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 436       |
# |    ep_rew_mean     | -1.03e+05 |
# | time/              |           |
# |    episodes        | 188       |
# |    fps             | 171       |
# |    time_elapsed    | 457       |
# |    total_timesteps | 78320     |
# | train/             |           |
# |    actor_loss      | 9.03e+03  |
# |    critic_loss     | 3.17e+06  |
# |    ent_coef        | 37.5      |
# |    ent_coef_loss   | 1.2       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19554     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 442       |
# |    ep_rew_mean     | -1.02e+05 |
# | time/              |           |
# |    episodes        | 192       |
# |    fps             | 171       |
# |    time_elapsed    | 467       |
# |    total_timesteps | 80112     |
# | train/             |           |
# |    actor_loss      | 9.06e+03  |
# |    critic_loss     | 3.81e+06  |
# |    ent_coef        | 36.6      |
# |    ent_coef_loss   | -1.1      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20002     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 445       |
# |    ep_rew_mean     | -9.89e+04 |
# | time/              |           |
# |    episodes        | 196       |
# |    fps             | 171       |
# |    time_elapsed    | 482       |
# |    total_timesteps | 82628     |
# | train/             |           |
# |    actor_loss      | 8.4e+03   |
# |    critic_loss     | 5.86e+07  |
# |    ent_coef        | 35.6      |
# |    ent_coef_loss   | 0.367     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20631     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 440       |
# |    ep_rew_mean     | -9.87e+04 |
# | time/              |           |
# |    episodes        | 200       |
# |    fps             | 171       |
# |    time_elapsed    | 492       |
# |    total_timesteps | 84452     |
# | train/             |           |
# |    actor_loss      | 8.21e+03  |
# |    critic_loss     | 1.26e+07  |
# |    ent_coef        | 34.9      |
# |    ent_coef_loss   | 1.31      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21087     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 442       |
# |    ep_rew_mean     | -9.18e+04 |
# | time/              |           |
# |    episodes        | 204       |
# |    fps             | 171       |
# |    time_elapsed    | 503       |
# |    total_timesteps | 86304     |
# | train/             |           |
# |    actor_loss      | 9.14e+03  |
# |    critic_loss     | 3.56e+06  |
# |    ent_coef        | 33.1      |
# |    ent_coef_loss   | 0.541     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21550     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 453       |
# |    ep_rew_mean     | -7.87e+04 |
# | time/              |           |
# |    episodes        | 208       |
# |    fps             | 171       |
# |    time_elapsed    | 521       |
# |    total_timesteps | 89348     |
# | train/             |           |
# |    actor_loss      | 9.03e+03  |
# |    critic_loss     | 4.42e+06  |
# |    ent_coef        | 32.4      |
# |    ent_coef_loss   | 0.154     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22311     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 460      |
# |    ep_rew_mean     | -7.8e+04 |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 171      |
# |    time_elapsed    | 534      |
# |    total_timesteps | 91508    |
# | train/             |          |
# |    actor_loss      | 7.72e+03 |
# |    critic_loss     | 2.1e+06  |
# |    ent_coef        | 31.7     |
# |    ent_coef_loss   | 0.98     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22851    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 470       |
# |    ep_rew_mean     | -7.56e+04 |
# | time/              |           |
# |    episodes        | 216       |
# |    fps             | 171       |
# |    time_elapsed    | 543       |
# |    total_timesteps | 93040     |
# | train/             |           |
# |    actor_loss      | 7.53e+03  |
# |    critic_loss     | 2.08e+06  |
# |    ent_coef        | 31        |
# |    ent_coef_loss   | 0.358     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23234     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 456       |
# |    ep_rew_mean     | -7.67e+04 |
# | time/              |           |
# |    episodes        | 220       |
# |    fps             | 171       |
# |    time_elapsed    | 552       |
# |    total_timesteps | 94652     |
# | train/             |           |
# |    actor_loss      | 7.81e+03  |
# |    critic_loss     | 2.87e+06  |
# |    ent_coef        | 31        |
# |    ent_coef_loss   | -0.407    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23637     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 462       |
# |    ep_rew_mean     | -7.68e+04 |
# | time/              |           |
# |    episodes        | 224       |
# |    fps             | 171       |
# |    time_elapsed    | 570       |
# |    total_timesteps | 97712     |
# | train/             |           |
# |    actor_loss      | 7.48e+03  |
# |    critic_loss     | 3.39e+06  |
# |    ent_coef        | 29.2      |
# |    ent_coef_loss   | -0.774    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24402     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 466       |
# |    ep_rew_mean     | -7.49e+04 |
# | time/              |           |
# |    episodes        | 228       |
# |    fps             | 171       |
# |    time_elapsed    | 588       |
# |    total_timesteps | 100708    |
# | train/             |           |
# |    actor_loss      | 7.82e+03  |
# |    critic_loss     | 7.95e+06  |
# |    ent_coef        | 28.3      |
# |    ent_coef_loss   | 0.188     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25151     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 477       |
# |    ep_rew_mean     | -7.28e+04 |
# | time/              |           |
# |    episodes        | 232       |
# |    fps             | 171       |
# |    time_elapsed    | 600       |
# |    total_timesteps | 102748    |
# | train/             |           |
# |    actor_loss      | 7.42e+03  |
# |    critic_loss     | 4.54e+06  |
# |    ent_coef        | 28        |
# |    ent_coef_loss   | -1.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25661     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 475       |
# |    ep_rew_mean     | -6.96e+04 |
# | time/              |           |
# |    episodes        | 236       |
# |    fps             | 171       |
# |    time_elapsed    | 619       |
# |    total_timesteps | 106096    |
# | train/             |           |
# |    actor_loss      | 7.84e+03  |
# |    critic_loss     | 1.84e+07  |
# |    ent_coef        | 28        |
# |    ent_coef_loss   | 0.807     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 26498     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 477       |
# |    ep_rew_mean     | -6.74e+04 |
# | time/              |           |
# |    episodes        | 240       |
# |    fps             | 171       |
# |    time_elapsed    | 628       |
# |    total_timesteps | 107616    |
# | train/             |           |
# |    actor_loss      | 7.67e+03  |
# |    critic_loss     | 3.65e+06  |
# |    ent_coef        | 26.1      |
# |    ent_coef_loss   | 0.0887    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 26878     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 487      |
# |    ep_rew_mean     | -5.9e+04 |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 171      |
# |    time_elapsed    | 648      |
# |    total_timesteps | 110980   |
# | train/             |          |
# |    actor_loss      | 6.17e+03 |
# |    critic_loss     | 3.44e+06 |
# |    ent_coef        | 25.5     |
# |    ent_coef_loss   | -0.207   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27719    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 493      |
# |    ep_rew_mean     | -5.9e+04 |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 171      |
# |    time_elapsed    | 664      |
# |    total_timesteps | 113704   |
# | train/             |          |
# |    actor_loss      | 5.91e+03 |
# |    critic_loss     | 4.23e+07 |
# |    ent_coef        | 25.5     |
# |    ent_coef_loss   | 1.21     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28400    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 508      |
# |    ep_rew_mean     | -5.6e+04 |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 171      |
# |    time_elapsed    | 676      |
# |    total_timesteps | 115724   |
# | train/             |          |
# |    actor_loss      | 5.7e+03  |
# |    critic_loss     | 6.65e+07 |
# |    ent_coef        | 23.9     |
# |    ent_coef_loss   | -0.168   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28905    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 519       |
# |    ep_rew_mean     | -5.51e+04 |
# | time/              |           |
# |    episodes        | 256       |
# |    fps             | 171       |
# |    time_elapsed    | 690       |
# |    total_timesteps | 118260    |
# | train/             |           |
# |    actor_loss      | 6.64e+03  |
# |    critic_loss     | 2.98e+06  |
# |    ent_coef        | 25        |
# |    ent_coef_loss   | 0.176     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 29539     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 538       |
# |    ep_rew_mean     | -5.41e+04 |
# | time/              |           |
# |    episodes        | 260       |
# |    fps             | 171       |
# |    time_elapsed    | 708       |
# |    total_timesteps | 121316    |
# | train/             |           |
# |    actor_loss      | 5.83e+03  |
# |    critic_loss     | 3.27e+07  |
# |    ent_coef        | 25.2      |
# |    ent_coef_loss   | 1.32      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30303     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 542       |
# |    ep_rew_mean     | -4.99e+04 |
# | time/              |           |
# |    episodes        | 264       |
# |    fps             | 171       |
# |    time_elapsed    | 729       |
# |    total_timesteps | 124952    |
# | train/             |           |
# |    actor_loss      | 6.16e+03  |
# |    critic_loss     | 1.73e+07  |
# |    ent_coef        | 23.1      |
# |    ent_coef_loss   | -0.0556   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31212     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 564       |
# |    ep_rew_mean     | -4.82e+04 |
# | time/              |           |
# |    episodes        | 268       |
# |    fps             | 171       |
# |    time_elapsed    | 737       |
# |    total_timesteps | 126244    |
# | train/             |           |
# |    actor_loss      | 5.15e+03  |
# |    critic_loss     | 4.46e+06  |
# |    ent_coef        | 23.2      |
# |    ent_coef_loss   | 0.603     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31535     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 556       |
# |    ep_rew_mean     | -4.63e+04 |
# | time/              |           |
# |    episodes        | 272       |
# |    fps             | 171       |
# |    time_elapsed    | 752       |
# |    total_timesteps | 128832    |
# | train/             |           |
# |    actor_loss      | 5.41e+03  |
# |    critic_loss     | 3.38e+06  |
# |    ent_coef        | 24        |
# |    ent_coef_loss   | 0.879     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32182     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 571       |
# |    ep_rew_mean     | -4.46e+04 |
# | time/              |           |
# |    episodes        | 276       |
# |    fps             | 171       |
# |    time_elapsed    | 759       |
# |    total_timesteps | 130072    |
# | train/             |           |
# |    actor_loss      | 4.24e+03  |
# |    critic_loss     | 2.51e+06  |
# |    ent_coef        | 22.3      |
# |    ent_coef_loss   | 0.428     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32492     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 586       |
# |    ep_rew_mean     | -4.02e+04 |
# | time/              |           |
# |    episodes        | 280       |
# |    fps             | 171       |
# |    time_elapsed    | 782       |
# |    total_timesteps | 133916    |
# | train/             |           |
# |    actor_loss      | 4.37e+03  |
# |    critic_loss     | 8.36e+06  |
# |    ent_coef        | 21        |
# |    ent_coef_loss   | -1.87     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33453     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 594       |
# |    ep_rew_mean     | -3.51e+04 |
# | time/              |           |
# |    episodes        | 284       |
# |    fps             | 171       |
# |    time_elapsed    | 794       |
# |    total_timesteps | 135908    |
# | train/             |           |
# |    actor_loss      | 4.29e+03  |
# |    critic_loss     | 1.99e+06  |
# |    ent_coef        | 21.6      |
# |    ent_coef_loss   | 1.02      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33951     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 612       |
# |    ep_rew_mean     | -3.35e+04 |
# | time/              |           |
# |    episodes        | 288       |
# |    fps             | 171       |
# |    time_elapsed    | 809       |
# |    total_timesteps | 138628    |
# | train/             |           |
# |    actor_loss      | 4.37e+03  |
# |    critic_loss     | 1.47e+06  |
# |    ent_coef        | 21.6      |
# |    ent_coef_loss   | 1.32      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34631     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 611       |
# |    ep_rew_mean     | -3.26e+04 |
# | time/              |           |
# |    episodes        | 292       |
# |    fps             | 171       |
# |    time_elapsed    | 830       |
# |    total_timesteps | 142164    |
# | train/             |           |
# |    actor_loss      | 3.19e+03  |
# |    critic_loss     | 3.33e+07  |
# |    ent_coef        | 20.1      |
# |    ent_coef_loss   | 0.0188    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35515     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 626       |
# |    ep_rew_mean     | -3.12e+04 |
# | time/              |           |
# |    episodes        | 296       |
# |    fps             | 171       |
# |    time_elapsed    | 854       |
# |    total_timesteps | 146164    |
# | train/             |           |
# |    actor_loss      | 2.81e+03  |
# |    critic_loss     | 1.46e+06  |
# |    ent_coef        | 20.4      |
# |    ent_coef_loss   | 0.583     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36515     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 643       |
# |    ep_rew_mean     | -2.86e+04 |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 171       |
# |    time_elapsed    | 875       |
# |    total_timesteps | 149916    |
# | train/             |           |
# |    actor_loss      | 2.83e+03  |
# |    critic_loss     | 5.3e+07   |
# |    ent_coef        | 19        |
# |    ent_coef_loss   | -0.316    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 37453     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 652       |
# |    ep_rew_mean     | -2.78e+04 |
# | time/              |           |
# |    episodes        | 304       |
# |    fps             | 171       |
# |    time_elapsed    | 883       |
# |    total_timesteps | 151092    |
# | train/             |           |
# |    actor_loss      | 2.81e+03  |
# |    critic_loss     | 1.02e+07  |
# |    ent_coef        | 19.2      |
# |    ent_coef_loss   | -1.46     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 37747     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 650       |
# |    ep_rew_mean     | -2.76e+04 |
# | time/              |           |
# |    episodes        | 308       |
# |    fps             | 171       |
# |    time_elapsed    | 898       |
# |    total_timesteps | 153852    |
# | train/             |           |
# |    actor_loss      | 2.58e+03  |
# |    critic_loss     | 6.55e+06  |
# |    ent_coef        | 20.8      |
# |    ent_coef_loss   | -2.57     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 38437     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 655       |
# |    ep_rew_mean     | -2.64e+04 |
# | time/              |           |
# |    episodes        | 312       |
# |    fps             | 171       |
# |    time_elapsed    | 921       |
# |    total_timesteps | 157752    |
# | train/             |           |
# |    actor_loss      | 1.93e+03  |
# |    critic_loss     | 6.63e+06  |
# |    ent_coef        | 18.1      |
# |    ent_coef_loss   | 0.127     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 39412     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 661       |
# |    ep_rew_mean     | -2.91e+04 |
# | time/              |           |
# |    episodes        | 316       |
# |    fps             | 171       |
# |    time_elapsed    | 942       |
# |    total_timesteps | 161308    |
# | train/             |           |
# |    actor_loss      | 849       |
# |    critic_loss     | 3.15e+06  |
# |    ent_coef        | 17.8      |
# |    ent_coef_loss   | -0.854    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 40301     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 687       |
# |    ep_rew_mean     | -2.62e+04 |
# | time/              |           |
# |    episodes        | 320       |
# |    fps             | 171       |
# |    time_elapsed    | 961       |
# |    total_timesteps | 164624    |
# | train/             |           |
# |    actor_loss      | 220       |
# |    critic_loss     | 7.7e+06   |
# |    ent_coef        | 17.3      |
# |    ent_coef_loss   | -1.35     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 41130     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 697       |
# |    ep_rew_mean     | -2.16e+04 |
# | time/              |           |
# |    episodes        | 324       |
# |    fps             | 171       |
# ...
# |    ent_coef        | 9.51     |
# |    ent_coef_loss   | 3.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2473016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.59e+04 |
# | time/              |          |
# |    episodes        | 29184    |
# |    fps             | 142      |
# |    time_elapsed    | 69578    |
# |    total_timesteps | 9896168  |
# | train/             |          |
# |    actor_loss      | 1.62e+04 |
# |    critic_loss     | 1.95e+06 |
# |    ent_coef        | 7.24     |
# |    ent_coef_loss   | 2.08     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2474016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.57e+04 |
# | time/              |          |
# |    episodes        | 29188    |
# |    fps             | 142      |
# |    time_elapsed    | 69606    |
# |    total_timesteps | 9900168  |
# | train/             |          |
# |    actor_loss      | 1.98e+04 |
# |    critic_loss     | 3.58e+06 |
# |    ent_coef        | 6.42     |
# |    ent_coef_loss   | -0.451   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2475016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.58e+04 |
# | time/              |          |
# |    episodes        | 29192    |
# |    fps             | 142      |
# |    time_elapsed    | 69634    |
# |    total_timesteps | 9904168  |
# | train/             |          |
# |    actor_loss      | 2.05e+04 |
# |    critic_loss     | 1.14e+06 |
# |    ent_coef        | 6.22     |
# |    ent_coef_loss   | -0.335   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2476016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.59e+04 |
# | time/              |          |
# |    episodes        | 29196    |
# |    fps             | 142      |
# |    time_elapsed    | 69662    |
# |    total_timesteps | 9908168  |
# | train/             |          |
# |    actor_loss      | 1.8e+04  |
# |    critic_loss     | 2.86e+06 |
# |    ent_coef        | 5.95     |
# |    ent_coef_loss   | 0.408    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2477016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.5e+04  |
# | time/              |          |
# |    episodes        | 29200    |
# |    fps             | 142      |
# |    time_elapsed    | 69690    |
# |    total_timesteps | 9912168  |
# | train/             |          |
# |    actor_loss      | 1.88e+04 |
# |    critic_loss     | 8.11e+05 |
# |    ent_coef        | 5.32     |
# |    ent_coef_loss   | 0.0456   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2478016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.49e+04 |
# | time/              |          |
# |    episodes        | 29204    |
# |    fps             | 142      |
# |    time_elapsed    | 69718    |
# |    total_timesteps | 9916168  |
# | train/             |          |
# |    actor_loss      | 1.86e+04 |
# |    critic_loss     | 2.48e+06 |
# |    ent_coef        | 5.26     |
# |    ent_coef_loss   | 0.105    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2479016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.47e+04 |
# | time/              |          |
# |    episodes        | 29208    |
# |    fps             | 142      |
# |    time_elapsed    | 69746    |
# |    total_timesteps | 9920168  |
# | train/             |          |
# |    actor_loss      | 1.66e+04 |
# |    critic_loss     | 8.08e+05 |
# |    ent_coef        | 5.15     |
# |    ent_coef_loss   | 0.623    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2480016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.41e+04 |
# | time/              |          |
# |    episodes        | 29212    |
# |    fps             | 142      |
# |    time_elapsed    | 69773    |
# |    total_timesteps | 9924168  |
# | train/             |          |
# |    actor_loss      | 1.59e+04 |
# |    critic_loss     | 9.79e+05 |
# |    ent_coef        | 4.81     |
# |    ent_coef_loss   | 0.354    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2481016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.38e+04 |
# | time/              |          |
# |    episodes        | 29216    |
# |    fps             | 142      |
# |    time_elapsed    | 69801    |
# |    total_timesteps | 9928168  |
# | train/             |          |
# |    actor_loss      | 1.63e+04 |
# |    critic_loss     | 1.87e+06 |
# |    ent_coef        | 5.75     |
# |    ent_coef_loss   | -1.42    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2482016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.36e+04 |
# | time/              |          |
# |    episodes        | 29220    |
# |    fps             | 142      |
# |    time_elapsed    | 69830    |
# |    total_timesteps | 9932168  |
# | train/             |          |
# |    actor_loss      | 1.68e+04 |
# |    critic_loss     | 1.37e+06 |
# |    ent_coef        | 5.77     |
# |    ent_coef_loss   | -0.0376  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2483016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.54e+04 |
# | time/              |          |
# |    episodes        | 29224    |
# |    fps             | 142      |
# |    time_elapsed    | 69858    |
# |    total_timesteps | 9936168  |
# | train/             |          |
# |    actor_loss      | 1.77e+04 |
# |    critic_loss     | 1.94e+06 |
# |    ent_coef        | 7.22     |
# |    ent_coef_loss   | 1.17     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2484016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.61e+04 |
# | time/              |          |
# |    episodes        | 29228    |
# |    fps             | 142      |
# |    time_elapsed    | 69886    |
# |    total_timesteps | 9940168  |
# | train/             |          |
# |    actor_loss      | 2.38e+04 |
# |    critic_loss     | 3.27e+06 |
# |    ent_coef        | 6.72     |
# |    ent_coef_loss   | -4.15    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2485016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.63e+04 |
# | time/              |          |
# |    episodes        | 29232    |
# |    fps             | 142      |
# |    time_elapsed    | 69914    |
# |    total_timesteps | 9944168  |
# | train/             |          |
# |    actor_loss      | 2.48e+04 |
# |    critic_loss     | 2.59e+06 |
# |    ent_coef        | 6.51     |
# |    ent_coef_loss   | -0.366   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2486016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.62e+04 |
# | time/              |          |
# |    episodes        | 29236    |
# |    fps             | 142      |
# |    time_elapsed    | 69942    |
# |    total_timesteps | 9948168  |
# | train/             |          |
# |    actor_loss      | 2.8e+04  |
# |    critic_loss     | 3.69e+06 |
# |    ent_coef        | 6.16     |
# |    ent_coef_loss   | 1.39     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2487016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.62e+04 |
# | time/              |          |
# |    episodes        | 29240    |
# |    fps             | 142      |
# |    time_elapsed    | 69970    |
# |    total_timesteps | 9952168  |
# | train/             |          |
# |    actor_loss      | 2.31e+04 |
# |    critic_loss     | 7e+05    |
# |    ent_coef        | 4.42     |
# |    ent_coef_loss   | 0.373    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2488016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | 1.54e+04 |
# | time/              |          |
# |    episodes        | 29244    |
# |    fps             | 142      |
# |    time_elapsed    | 69998    |
# |    total_timesteps | 9956168  |
# | train/             |          |
# |    actor_loss      | 3.41e+04 |
# |    critic_loss     | 7.57e+06 |
# |    ent_coef        | 7.37     |
# |    ent_coef_loss   | -4.83    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2489016  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -3.13e+04 |
# | time/              |           |
# |    episodes        | 29248     |
# |    fps             | 142       |
# |    time_elapsed    | 70026     |
# |    total_timesteps | 9960168   |
# | train/             |           |
# |    actor_loss      | 3.78e+04  |
# |    critic_loss     | 4.66e+06  |
# |    ent_coef        | 12.3      |
# |    ent_coef_loss   | -0.323    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2490016   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -4.16e+04 |
# | time/              |           |
# |    episodes        | 29252     |
# |    fps             | 142       |
# |    time_elapsed    | 70053     |
# |    total_timesteps | 9964168   |
# | train/             |           |
# |    actor_loss      | 3.84e+04  |
# |    critic_loss     | 2.67e+06  |
# |    ent_coef        | 12.1      |
# |    ent_coef_loss   | -2.96     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2491016   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -4.32e+04 |
# | time/              |           |
# |    episodes        | 29256     |
# |    fps             | 142       |
# |    time_elapsed    | 70081     |
# |    total_timesteps | 9968168   |
# | train/             |           |
# |    actor_loss      | 3.47e+04  |
# |    critic_loss     | 4.65e+06  |
# |    ent_coef        | 11.1      |
# |    ent_coef_loss   | 1.87      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2492016   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -4.44e+04 |
# | time/              |           |
# |    episodes        | 29260     |
# |    fps             | 142       |
# |    time_elapsed    | 70108     |
# |    total_timesteps | 9972168   |
# | train/             |           |
# |    actor_loss      | 3.1e+04   |
# |    critic_loss     | 3.48e+06  |
# |    ent_coef        | 11.2      |
# |    ent_coef_loss   | 1.05      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2493016   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -4.58e+04 |
# | time/              |           |
# |    episodes        | 29264     |
# |    fps             | 142       |
# |    time_elapsed    | 70137     |
# |    total_timesteps | 9976168   |
# | train/             |           |
# |    actor_loss      | 2.47e+04  |
# |    critic_loss     | 1.64e+06  |
# |    ent_coef        | 10.3      |
# |    ent_coef_loss   | 1.71      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2494016   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -4.69e+04 |
# | time/              |           |
# |    episodes        | 29268     |
# |    fps             | 142       |
# |    time_elapsed    | 70165     |
# |    total_timesteps | 9980168   |
# | train/             |           |
# |    actor_loss      | 1.96e+04  |
# |    critic_loss     | 1.99e+06  |
# |    ent_coef        | 9.18      |
# |    ent_coef_loss   | 0.231     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2495016   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -4.82e+04 |
# | time/              |           |
# |    episodes        | 29272     |
# |    fps             | 142       |
# |    time_elapsed    | 70194     |
# |    total_timesteps | 9984168   |
# | train/             |           |
# |    actor_loss      | 1.61e+04  |
# |    critic_loss     | 1.5e+06   |
# |    ent_coef        | 8.46      |
# |    ent_coef_loss   | 1.01      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2496016   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -4.87e+04 |
# | time/              |           |
# |    episodes        | 29276     |
# |    fps             | 142       |
# |    time_elapsed    | 70222     |
# |    total_timesteps | 9988168   |
# | train/             |           |
# |    actor_loss      | 1.25e+04  |
# |    critic_loss     | 1.5e+06   |
# |    ent_coef        | 8.12      |
# |    ent_coef_loss   | 0.0582    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2497016   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1e+03     |
# |    ep_rew_mean     | -4.84e+04 |
# | time/              |           |
# |    episodes        | 29280     |
# |    fps             | 142       |
# |    time_elapsed    | 70249     |
# |    total_timesteps | 9992168   |
# | train/             |           |
# |    actor_loss      | 1.01e+04  |
# |    critic_loss     | 1.25e+06  |
# |    ent_coef        | 7.44      |
# |    ent_coef_loss   | 0.843     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 2498016   |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -4.9e+04 |
# | time/              |          |
# |    episodes        | 29284    |
# |    fps             | 142      |
# |    time_elapsed    | 70275    |
# |    total_timesteps | 9996168  |
# | train/             |          |
# |    actor_loss      | 1.11e+04 |
# |    critic_loss     | 9.86e+05 |
# |    ent_coef        | 6.12     |
# |    ent_coef_loss   | 1.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2499016  |
# ---------------------------------
# Eval num_timesteps=10000000, episode_reward=10000.00 +/- 0.00
# Episode length: 1000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1e+03    |
# |    mean_reward     | 1e+04    |
# | time/              |          |
# |    total_timesteps | 10000000 |
# | train/             |          |
# |    actor_loss      | 1.05e+04 |
# |    critic_loss     | 1.14e+06 |
# |    ent_coef        | 6.12     |
# |    ent_coef_loss   | -0.804   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2499974  |
# ---------------------------------
# CPU times: total: 19h 27min 43s
# Wall time: 19h 31min 52s
